# %% [markdown]
# # **Setup**

# %%
import os, sys

# Repository information
REPO_NAME = "RecSys-Challenge-2025"
REPO_URL  = f"github.com/Lv1g1/{REPO_NAME}.git"

# Detect environment
IS_COLAB = 'content' in os.getcwd()
IS_KAGGLE = 'kaggle' in os.getcwd()
IS_LOCAL = not (IS_COLAB or IS_KAGGLE)

WORKING_DIR = os.getcwd()

if IS_COLAB:
    WORKING_DIR = "/content"

    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)

    # Get GitHub token via input
    def get_token():
        from getpass import getpass
        return getpass("GitHub Token: ")

elif IS_KAGGLE:
    WORKING_DIR = "/kaggle/working"

    # Get GitHub token from Kaggle secrets
    def get_token():
        from kaggle_secrets import UserSecretsClient
        return UserSecretsClient().get_secret("Token")

# If local environment assume inside the repo
LOCAL_REPO_PATH = "/home/luigi/RecSys" if IS_LOCAL else os.path.join(WORKING_DIR, REPO_NAME)

# Clone the repository if it doesn't exist
if not os.path.exists(LOCAL_REPO_PATH):
    os.chdir(WORKING_DIR)
    token = get_token()

    # !git clone https://{token}@{REPO_URL}
else:
    print("Repo already exists — pulling latest changes")
    os.chdir(LOCAL_REPO_PATH)
    # !git pull
    os.chdir(WORKING_DIR)

# Add to Python PATH
if LOCAL_REPO_PATH not in sys.path:
    sys.path.append(LOCAL_REPO_PATH)
# Out:
# Repo already exists — pulling latest changes
# Already up to date.

# %%
if IS_COLAB or False:  # Set to True if you want to recompile Cython files
    os.chdir(LOCAL_REPO_PATH)
    # !python run_compile_all_cython.py
    os.chdir(WORKING_DIR)

# %%
if IS_COLAB or IS_KAGGLE:
    # !pip install optuna

import optuna

# %%
import importlib
import scipy.sparse as sps
import pandas as pd
import numpy as np

from Challenge import paths
importlib.reload(paths)

from Challenge.hyper_tuning import hyperparameter_tuning
# Out:
# Running on local — storage at: /home/luigi/RecSys
# Running on local — storage at: /home/luigi/RecSys

# %% [markdown]
# # **Load Data**

# %%
# Load datasets
URM_train = sps.load_npz(paths.URM_TRAIN)
URM_validation = sps.load_npz(paths.URM_VALIDATION)

# %%
def evaluate_recommender(recommender, at):
    cumulative_recall = 0.0
    num_eval = 0
    
    for user_id in range(URM_validation.shape[0]):
        relevant_items = URM_validation.indices[URM_validation.indptr[user_id]:URM_validation.indptr[user_id+1]]
        
        if len(relevant_items)>0:
            num_eval+=1
            
            recommended_items = recommender.recommend(user_id, cutoff=at)
            
            is_relevant = np.isin(recommended_items, relevant_items, assume_unique=True)
            recall_score = np.sum(is_relevant, dtype=np.float32) / relevant_items.shape[0]

            cumulative_recall += recall_score

    return cumulative_recall / num_eval

# %% [markdown]
# # **Hyperparameter search**

# %%
# Define objective function for hyperparameter tuning
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender

STUDY_NAME = SLIMElasticNetRecommender.RECOMMENDER_NAME

"""
Result from the first search

Best Value: 0.28934742868996155
Best Params: {'l1_ratio': 0.5342964541170618, 'alpha': 0.0005497715703344824, 'positive_only': False, 'topK': 640}

Best Value: 0.2900477994572642
Best Params: {'l1_ratio': 0.6257826858334088, 'alpha': 0.000818987106299432, 'topK': 646}
"""

def objective_function(optuna_trial: optuna.trial.Trial) -> float:
    recommender_instance = SLIMElasticNetRecommender(URM_train)
    recommender_instance.fit(
        l1_ratio=optuna_trial.suggest_float("l1_ratio", 0.3, 0.8),
        alpha=optuna_trial.suggest_float("alpha", 1e-6, 1e2, log=True),
        positive_only=False,
        topK=optuna_trial.suggest_int("topK", 600, 700, step=10)
    )

    return evaluate_recommender(recommender_instance, at=20)

# %%
# Perform hyperparameter tuning
save_results, optuna_study = hyperparameter_tuning(
    objective_function,
    study_name=STUDY_NAME,
    n_trials=40
)
# Out:
# [I 2025-11-08 21:33:16,883] Using an existing study with name 'SLIMElasticNetRecommender' instead of creating a new one.
#   0%|          | 0/40 [00:00<?, ?it/s]
# SLIMElasticNetRecommender: Processed 5914 (84.9%) in 5.00 min. Items per second: 19.71
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 5.85 min. Items per second: 19.85
# [I 2025-11-08 21:39:17,160] Trial 5 finished with value: 0.2869803011417389 and parameters: {'l1_ratio': 0.6017863899345268, 'alpha': 0.0003694964520269354, 'topK': 600}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 56.26 sec. Items per second: 123.85
# [I 2025-11-08 21:40:19,186] Trial 6 finished with value: 0.08244768530130386 and parameters: {'l1_ratio': 0.640492049425272, 'alpha': 0.13261708941361136, 'topK': 600}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 1538 (22.1%) in 5.00 min. Items per second: 5.12
# SLIMElasticNetRecommender: Processed 3200 (45.9%) in 10.00 min. Items per second: 5.33
# SLIMElasticNetRecommender: Processed 4706 (67.5%) in 15.01 min. Items per second: 5.23
# SLIMElasticNetRecommender: Processed 6226 (89.3%) in 20.01 min. Items per second: 5.19
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 22.34 min. Items per second: 5.20
# [I 2025-11-08 22:02:46,957] Trial 7 finished with value: 0.20783451199531555 and parameters: {'l1_ratio': 0.7904635996179159, 'alpha': 1.714621792374228e-05, 'topK': 610}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 49.89 sec. Items per second: 139.68
# [I 2025-11-08 22:03:42,607] Trial 8 finished with value: 0.0032129050232470036 and parameters: {'l1_ratio': 0.3687050438065898, 'alpha': 57.455024808922104, 'topK': 670}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 49.59 sec. Items per second: 140.52
# [I 2025-11-08 22:04:37,847] Trial 9 finished with value: 0.0032129050232470036 and parameters: {'l1_ratio': 0.502171236294902, 'alpha': 77.87290793940666, 'topK': 610}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 53.33 sec. Items per second: 130.65
# [I 2025-11-08 22:05:34,306] Trial 10 finished with value: 0.16389253735542297 and parameters: {'l1_ratio': 0.4407718825491608, 'alpha': 0.08369341520672796, 'topK': 670}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 1.46 min. Items per second: 79.57
# [I 2025-11-08 22:07:05,515] Trial 11 finished with value: 0.24798670411109924 and parameters: {'l1_ratio': 0.4096398146357892, 'alpha': 0.018861984650484324, 'topK': 630}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 944 (13.5%) in 5.00 min. Items per second: 3.14
# SLIMElasticNetRecommender: Processed 1840 (26.4%) in 10.02 min. Items per second: 3.06
# SLIMElasticNetRecommender: Processed 2450 (35.2%) in 15.02 min. Items per second: 2.72
# SLIMElasticNetRecommender: Processed 3075 (44.1%) in 20.02 min. Items per second: 2.56
# SLIMElasticNetRecommender: Processed 3691 (53.0%) in 25.02 min. Items per second: 2.46
# SLIMElasticNetRecommender: Processed 4304 (61.8%) in 30.03 min. Items per second: 2.39
# SLIMElasticNetRecommender: Processed 4920 (70.6%) in 35.03 min. Items per second: 2.34
# SLIMElasticNetRecommender: Processed 5548 (79.6%) in 40.04 min. Items per second: 2.31
# SLIMElasticNetRecommender: Processed 6212 (89.1%) in 45.04 min. Items per second: 2.30
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 48.90 min. Items per second: 2.38
# [I 2025-11-08 22:56:04,109] Trial 12 finished with value: 0.18932676315307617 and parameters: {'l1_ratio': 0.3787121602890203, 'alpha': 3.6874923446400867e-06, 'topK': 640}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 5716 (82.0%) in 5.00 min. Items per second: 19.05
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 8.03 min. Items per second: 14.47
# [I 2025-11-08 23:04:16,840] Trial 13 finished with value: 0.2820395827293396 and parameters: {'l1_ratio': 0.6417496715888258, 'alpha': 0.00023336361583269384, 'topK': 700}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 3714 (53.3%) in 5.00 min. Items per second: 12.37
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 9.27 min. Items per second: 12.52
# [I 2025-11-08 23:13:47,741] Trial 14 finished with value: 0.28116312623023987 and parameters: {'l1_ratio': 0.625470450144506, 'alpha': 0.00022926201714165798, 'topK': 700}. Best is trial 5 with value: 0.2869803011417389.
# SLIMElasticNetRecommender: Processed 4439 (63.7%) in 5.00 min. Items per second: 14.79
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 7.64 min. Items per second: 15.21
# [I 2025-11-08 23:21:41,266] Trial 15 finished with value: 0.2885260581970215 and parameters: {'l1_ratio': 0.6686357915029861, 'alpha': 0.0003732510537561539, 'topK': 700}. Best is trial 15 with value: 0.2885260581970215.
# SLIMElasticNetRecommender: Processed 5058 (72.6%) in 5.00 min. Items per second: 16.85
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 6.60 min. Items per second: 17.59
# [I 2025-11-08 23:28:24,250] Trial 16 finished with value: 0.28988751769065857 and parameters: {'l1_ratio': 0.7213269350687483, 'alpha': 0.00049529353731285, 'topK': 670}. Best is trial 16 with value: 0.28988751769065857.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 2.40 min. Items per second: 48.35
# [I 2025-11-08 23:30:53,126] Trial 17 finished with value: 0.2835610508918762 and parameters: {'l1_ratio': 0.7092594354334796, 'alpha': 0.0020982157125871643, 'topK': 680}. Best is trial 16 with value: 0.28988751769065857.
# SLIMElasticNetRecommender: Processed 1269 (18.2%) in 5.00 min. Items per second: 4.22
# SLIMElasticNetRecommender: Processed 2562 (36.8%) in 10.01 min. Items per second: 4.27
# SLIMElasticNetRecommender: Processed 3998 (57.4%) in 15.01 min. Items per second: 4.44
# SLIMElasticNetRecommender: Processed 6115 (87.7%) in 20.01 min. Items per second: 5.09
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 22.98 min. Items per second: 5.05
# [I 2025-11-08 23:54:01,992] Trial 18 finished with value: 0.21355098485946655 and parameters: {'l1_ratio': 0.7231892154399181, 'alpha': 2.4664355717228212e-05, 'topK': 680}. Best is trial 16 with value: 0.28988751769065857.
# SLIMElasticNetRecommender: Processed 6969 (100.0%) in 1.32 min. Items per second: 88.12
# [I 2025-11-08 23:55:27,096] Trial 19 finished with value: 0.0032129050232470036 and parameters: {'l1_ratio': 0.7189625986554395, 'alpha': 1.8872191623872363, 'topK': 660}. Best is trial 16 with value: 0.28988751769065857.
# SLIMElasticNetRecommender: Processed 654 ( 9.4%) in 5.00 min. Items per second: 2.17
# SLIMElasticNetRecommender: Processed 1234 (17.7%) in 10.01 min. Items per second: 2.05
# SLIMElasticNetRecommender: Processed 2059 (29.5%) in 15.01 min. Items per second: 2.29
# SLIMElasticNetRecommender: Processed 3026 (43.4%) in 20.01 min. Items per second: 2.52
# SLIMElasticNetRecommender: Processed 4000 (57.4%) in 25.01 min. Items per second: 2.66
# SLIMElasticNetRecommender: Processed 4940 (70.9%) in 30.02 min. Items per second: 2.74
# [W 2025-11-09 00:26:53,480] Trial 20 failed with parameters: {'l1_ratio': 0.550406251456764, 'alpha': 1.5832347933586761e-06, 'topK': 690} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_332960/4018880467.py", line 18, in objective_function
#     recommender_instance.fit(
#     ~~~~~~~~~~~~~~~~~~~~~~~~^
#         l1_ratio=optuna_trial.suggest_float("l1_ratio", 0.3, 0.8),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         topK=optuna_trial.suggest_int("topK", 600, 700, step=10)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/sklearn/utils/_testing.py", line 145, in wrapper
#     return fn(*args, **kwargs)
#   File "/home/luigi/RecSys/Recommenders/SLIM/SLIMElasticNetRecommender.py", line 87, in fit
#     self.model.fit(URM_train, y)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/sklearn/base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py", line 1084, in fit
#     _, this_coef, this_dual_gap, this_iter = self.path(
#                                              ~~~~~~~~~^
#         X,
#         ^^
#     ...<20 lines>...
#         sample_weight=sample_weight,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/sklearn/utils/_param_validation.py", line 191, in wrapper
#     return func(*args, **kwargs)
#   File "/home/luigi/.venvs/recsys/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py", line 656, in enet_path
#     model = cd_fast.sparse_enet_coordinate_descent(
#         w=coef_,
#     ...<12 lines>...
#         positive=positive,
#     )
# KeyboardInterrupt
# [W 2025-11-09 00:26:53,490] Trial 20 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Perform hyperparameter tuning
# ----> 2 save_results, optuna_study = hyperparameter_tuning(
#       3     objective_function,
#       4     study_name=STUDY_NAME,
#       5     n_trials=40
#       6 )
#
# File ~/RecSys/Challenge/hyper_tuning.py:30, in hyperparameter_tuning(objective_function, study_name, n_trials, storage)
#      21 study = optuna.create_study(
#      22     study_name=study_name,
#      23     storage=storage,
#      24     direction="maximize",
#      25     load_if_exists=True
#      26 )
#      28 callback = SaveResults()
# ---> 30 study.optimize(
#      31     objective_function,
#      32     callbacks=[callback],
#      33     n_trials=n_trials,
#      34     show_progress_bar=True
#      35 )
#      37 results_df = pd.DataFrame(callback.results)
#      39 # Print study results
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[7], line 18, in objective_function(optuna_trial)
#      16 def objective_function(optuna_trial: optuna.trial.Trial) -> float:
#      17     recommender_instance = SLIMElasticNetRecommender(URM_train)
# ---> 18     recommender_instance.fit(
#      19         l1_ratio=optuna_trial.suggest_float("l1_ratio", 0.3, 0.8),
#      20         alpha=optuna_trial.suggest_float("alpha", 1e-6, 1e2, log=True),
#      21         positive_only=False,
#      22         topK=optuna_trial.suggest_int("topK", 600, 700, step=10)
#      23     )
#      25     return evaluate_recommender(recommender_instance, at=20)
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/sklearn/utils/_testing.py:145, in _IgnoreWarnings.__call__.<locals>.wrapper(*args, **kwargs)
#     143 with warnings.catch_warnings():
#     144     warnings.simplefilter("ignore", self.category)
# --> 145     return fn(*args, **kwargs)
#
# File ~/RecSys/Recommenders/SLIM/SLIMElasticNetRecommender.py:87, in SLIMElasticNetRecommender.fit(self, l1_ratio, alpha, positive_only, topK)
#      84 URM_train.data[start_pos: end_pos] = 0.0
#      86 # fit one ElasticNet model per column
# ---> 87 self.model.fit(URM_train, y)
#      89 # self.model.coef_ contains the coefficient of the ElasticNet model
#      90 # let's keep only the non-zero values
#      91 nonzero_model_coef_index = self.model.sparse_coef_.indices
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:1084, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#    1082 else:
#    1083     this_Xy = None
# -> 1084 _, this_coef, this_dual_gap, this_iter = self.path(
#    1085     X,
#    1086     y[:, k],
#    1087     l1_ratio=self.l1_ratio,
#    1088     eps=None,
#    1089     n_alphas=None,
#    1090     alphas=[alpha],
#    1091     precompute=precompute,
#    1092     Xy=this_Xy,
#    1093     copy_X=True,
#    1094     coef_init=coef_[k],
#    1095     verbose=False,
#    1096     return_n_iter=True,
#    1097     positive=self.positive,
#    1098     check_input=False,
#    1099     # from here on **params
#    1100     tol=self.tol,
#    1101     X_offset=X_offset,
#    1102     X_scale=X_scale,
#    1103     max_iter=self.max_iter,
#    1104     random_state=self.random_state,
#    1105     selection=self.selection,
#    1106     sample_weight=sample_weight,
#    1107 )
#    1108 coef_[k] = this_coef[:, 0]
#    1109 dual_gaps_[k] = this_dual_gap[0]
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/.venvs/recsys/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:656, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     654 l2_reg = alpha * (1.0 - l1_ratio) * n_samples
#     655 if not multi_output and sparse.issparse(X):
# --> 656     model = cd_fast.sparse_enet_coordinate_descent(
#     657         w=coef_,
#     658         alpha=l1_reg,
#     659         beta=l2_reg,
#     660         X_data=X.data,
#     661         X_indices=X.indices,
#     662         X_indptr=X.indptr,
#     663         y=y,
#     664         sample_weight=sample_weight,
#     665         X_mean=X_sparse_scaling,
#     666         max_iter=max_iter,
#     667         tol=tol,
#     668         rng=rng,
#     669         random=random,
#     670         positive=positive,
#     671     )
#     672 elif multi_output:
#     673     model = cd_fast.enet_coordinate_descent_multi_task(
#     674         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random
#     675     )
#
# KeyboardInterrupt:

# %%
optuna.visualization.plot_optimization_history(optuna_study)

# %%
optuna.visualization.plot_param_importances(optuna_study)

# %%
optuna.visualization.plot_parallel_coordinate(optuna_study)

# %% [markdown]
# # **Hyperparameter tuning**

# %%
bp = optuna_study.best_trial.params

def refined_objective(trial):    
    recommender_instance = GlobalEffects(URM_train)
    recommender_instance.fit(
        lambda_user=trial.suggest_int("lambda_user", max(0, bp["lambda_user"]-100), bp["lambda_user"]+100),
        lambda_item=trial.suggest_int("lambda_item", max(0, bp["lambda_item"]-100), bp["lambda_item"]+100)
    )

    return evaluate_recommender(recommender_instance, at=20)

# %%
# Perform hyperparameter tuning
save_results, optuna_study = hyperparameter_tuning(
    refined_objective,
    study_name=STUDY_NAME+"_refined",
    n_trials=20
)

# %%
optuna.visualization.plot_optimization_history(optuna_study)

# %%
optuna.visualization.plot_param_importances(optuna_study)

# %%
optuna.visualization.plot_parallel_coordinate(optuna_study)

# %% [markdown]
# ## **Best Model**
# - ADD HERE

# %% [markdown]
# # **Train Model with best hyperparameter**

# %%
# Train final model on train + validation with best hyperparameters
recommender = GlobalEffects(URM_train + URM_validation)
recommender.fit(
    lambda_user=optuna_study.best_trial.params["lambda_user"],
    lambda_item=optuna_study.best_trial.params["lambda_item"]
)

# Save the trained model
recommender.save_model(paths.MODEL_DIR)

# %%
import pandas as pd

# Generate recommendations for the test set
user_ids_test = pd.read_csv(paths.CHALLENGE_USER_IDS_TEST)
ids = user_ids_test["user_id"].values

recommendations = recommender.recommend(ids, cutoff=20)

os.makedirs(paths.SUBMISSIONS, exist_ok=True)
with open(os.path.join(paths.SUBMISSIONS, STUDY_NAME + ".csv"), "w") as f:
    f.write("user_id,item_list\n")
    for user_id, rec_list in zip(ids, recommendations):
        f.write(f"{user_id},{' '.join([str(item) for item in rec_list])}\n")
