# %% [markdown]
# ## **Setup**

# %%
import os, sys

# Repository information
REPO_NAME = "RecSys-Challenge-2025"
REPO_URL  = f"github.com/Lv1g1/{REPO_NAME}.git"

# Detect environment
IS_COLAB = 'content' in os.getcwd()
IS_KAGGLE = 'kaggle' in os.getcwd()
IS_LOCAL = not (IS_COLAB or IS_KAGGLE)

WORKING_DIR = os.getcwd()

if IS_COLAB:
    WORKING_DIR = "/content"

    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)

    # Get GitHub token via input
    def get_token():
        from getpass import getpass
        return getpass("GitHub Token: ")

elif IS_KAGGLE:
    WORKING_DIR = "/kaggle/working"

    # Get GitHub token from Kaggle secrets
    def get_token():
        from kaggle_secrets import UserSecretsClient
        return UserSecretsClient().get_secret("Token")

# If local environment assume inside the repo
LOCAL_REPO_PATH = "/home/luigi/RecSys" if IS_LOCAL else os.path.join(WORKING_DIR, REPO_NAME)

# Clone the repository if it doesn't exist
if not os.path.exists(LOCAL_REPO_PATH):
    os.chdir(WORKING_DIR)
    token = get_token()

    # !git clone https://{token}@{REPO_URL}
else:
    print("Repo already exists — pulling latest changes")
    os.chdir(LOCAL_REPO_PATH)
    # !git pull
    os.chdir(WORKING_DIR)

# Add to Python PATH
if LOCAL_REPO_PATH not in sys.path:
    sys.path.append(LOCAL_REPO_PATH)

if IS_COLAB:
    # !pip install optuna
# Out:
# Repo already exists — pulling latest changes
# Already up to date.

# %%
if IS_COLAB or False:  # Set to True if you want to recompile Cython files
    os.chdir(LOCAL_REPO_PATH)
    # !python run_compile_all_cython.py
    os.chdir(WORKING_DIR)

# %% [markdown]
# ## **Imports**

# %%
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

from Challenge.paths import load_cv_folds, XGBOOST_MODELS
from Challenge.utils import load_models, evaluate_recommender, evaluate_recommender_implicit
# Out:
# Running on local — storage at: /home/luigi/RecSys

# %% [markdown]
# ## **Load Data**

# %%
folds = load_cv_folds(5)

# %% [markdown]
# ## **Load all Models**

# %%
from Recommenders.NonPersonalizedRecommender import TopPop
from Recommenders.KNN.UserKNNCFRecommender import UserKNNCFRecommender
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.SLIM.SLIMElasticNetRecommender import MultiThreadSLIM_SLIMElasticNetRecommender
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_WARP_Cython
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_BPR_Cython
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_SVDpp_Cython

from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from implicit.cpu.als import AlternatingLeastSquares
from Recommenders.MatrixFactorization.NMFRecommender import NMFRecommender
from Recommenders.Neural.MultVAE_PyTorch_Recommender import MultVAERecommender_PyTorch_OptimizerMask

# %%
models_mapping = {
    'TopPop': TopPop,
    'ItemKNN_cosine': ItemKNNCFRecommender,
    'ItemKNN_jaccard': ItemKNNCFRecommender,
    'ItemKNN_asymmetric': ItemKNNCFRecommender,
    'ItemKNN_tversky': ItemKNNCFRecommender,
    'ItemKNN_dice': ItemKNNCFRecommender,
    'UserKNN_cosine': UserKNNCFRecommender,
    'UserKNN_jaccard': UserKNNCFRecommender,
    'UserKNN_asymmetric': UserKNNCFRecommender,
    'UserKNN_tversky': UserKNNCFRecommender,
    'UserKNN_dice': UserKNNCFRecommender,
    'EASE_R': EASE_R_Recommender,
    'P3alpha': P3alphaRecommender,
    'RP3beta': RP3betaRecommender,
    'IALS': AlternatingLeastSquares,
    'MatrixFactorization_WARP': MatrixFactorization_WARP_Cython,
    'MatrixFactorization_BPR': MatrixFactorization_BPR_Cython,
    # 'MatrixFactorization_SVDpp': MatrixFactorization_SVDpp_Cython,
    
    # 'SLIM_BPR': SLIM_BPR_Cython,
    'NMF': NMFRecommender,
    'MultVAE': MultVAERecommender_PyTorch_OptimizerMask,
    'SLIMElasticNet': MultiThreadSLIM_SLIMElasticNetRecommender
}

# %%
folder = os.path.join(XGBOOST_MODELS, "features")
outer_folder = os.path.join(folder, "outer_folds")

# %% [markdown]
# ## **Candidate Selection - Greedy Gain/Cost**

# %%
def get_user_batches(user_ids, batch_size=1000):
    for i in range(0, len(user_ids), batch_size):
        yield user_ids[i:i + batch_size]

# %%
def precumpute_recommendations(URM_train, user_ids, models_mapping, folder, max_cutoff):
    model_recs_cache = {}
    model_names = []
    for model_name, model in load_models(URM_train, models_mapping, folder, verbose=False):
        print(f"Precomputing recommendations for {model_name}...")
        model_names.append(model_name)

        if type(model) == AlternatingLeastSquares:
            recommended_items, scores = model.recommend(
                user_ids, 
                URM_train, 
                N=max_cutoff, 
                filter_already_liked_items=True
            )

        elif type(model) == MultVAERecommender_PyTorch_OptimizerMask:
            # Do in batches to avoid OOM in GPU
            recommended_items = []
            for user_batch in get_user_batches(user_ids, batch_size=500):
                batch_recs = model.recommend(user_batch, cutoff=max_cutoff)
                recommended_items.extend(batch_recs)
            recommended_items = recommended_items

        else:
            recommended_items = model.recommend(user_ids, cutoff=max_cutoff)

        model_recs_cache[model_name] = np.array(recommended_items)

    return model_recs_cache, model_names

# %%
def greedy_candidate_selection(URM_train, URM_val, model_names, model_recs_cache, cutoffs, budget):
    n_users, n_items = URM_train.shape
    current_candidates_mask = sps.csr_matrix((n_users, n_items), dtype=bool)

    URM_val_bool = URM_val.astype(bool)

    selected_cutoffs = {name: 0 for name in model_names}
    avg_candidate_count = 0
    total_gain = 0

    # Visualization history
    history_candidates = [0]
    history_recall = [0]
    history_ratios = []

    while avg_candidate_count < budget:
        best_cutoff_config = None
        best_ratio = -1
        best_gain = 0
        best_cost = 0

        # Iterate through pre-loaded models
        for model_name in model_names:
            current_cutoff = selected_cutoffs[model_name]
            
            # Get all possible future cutoffs
            future_cutoffs = [c for c in cutoffs if c > current_cutoff]

            # OPTIMIZATION: Only look at the next 3 steps.
            # If we are at 10, check [20, 30, 40]. 
            # We don't need to calculate cost/gain for 500 yet.
            # It is unlikely that skipping directly to very high cutoffs is optimal.
            search_horizon = future_cutoffs[:3]

            # Check potential next cutoffs
            for next_cutoff in search_horizon:
                if next_cutoff <= current_cutoff:
                    continue

                # --- VECTORIZED CHECK ---
                new_recs_slice = model_recs_cache[model_name][:, current_cutoff:next_cutoff]

                # Flatten the slice to create sparse matrix coordinates
                rows = np.repeat(np.arange(n_users), new_recs_slice.shape[1])
                cols = new_recs_slice.flatten()

                # Filter out items that are ALREADY selected
                data = np.ones(len(cols), dtype=bool)
                proposal_matrix = sps.csr_matrix((data, (rows, cols)), shape=(n_users, n_items))

                # "greater than" acts as set difference: (Proposal > Current)
                # If Proposal has 1 and Current has 1, result is False (already exists)
                # If Proposal has 1 and Current has 0, result is True (new item)
                # We use > instead of != to avoid 0 != 1 cases where we don't care
                new_items_mask = (proposal_matrix > current_candidates_mask)

                marginal_cost = new_items_mask.nnz

                if marginal_cost == 0:
                    continue

                # Calculate Gain (Intersection with Validation)
                # Element-wise multiplication (AND operation)
                hits_mask = new_items_mask.multiply(URM_val_bool)
                marginal_gain = hits_mask.nnz

                ratio = marginal_gain / marginal_cost

                # Maximize Ratio
                if ratio > best_ratio:
                    best_ratio = ratio
                    best_cutoff_config = (model_name, next_cutoff)
                    best_gain = marginal_gain
                    best_cost = marginal_cost
                    # Store the mask to avoid re-computing it in the update step
                    best_proposal_mask = new_items_mask

        if best_cutoff_config is None:
            print("No more positive movements possible.")
            break

        # Add the best found configuration
        best_model, best_step = best_cutoff_config
        selected_cutoffs[best_model] = best_step
        
        # Update global candidates with the pre-calculated mask
        # Logical OR update
        current_candidates_mask = current_candidates_mask + best_proposal_mask

        # Calculate new average
        total_candidates = current_candidates_mask.nnz
        avg_candidate_count = total_candidates / n_users

        # Update total gain and current recall
        total_gain += best_gain
        current_recall = total_gain / URM_val.getnnz()

        # Update history for plotting
        history_candidates.append(avg_candidate_count)
        history_recall.append(current_recall)
        history_ratios.append(best_ratio)

        print(f"Selected {best_model} @ {best_step}. "
            f"Ratio: {best_ratio:.5f}. "
            f"Cost: {best_cost}. "
            f"Avg Candidates: {avg_candidate_count:.2f}. "
            f"RECALL: {current_recall:.4f}")

    print("---------------------------------------------------")
    print("Final Selection:", selected_cutoffs)

    return selected_cutoffs, history_candidates, history_recall, history_ratios

# %%
def plot_cv_history(cv_histories, max_budget=300):
    fig, ax1 = plt.subplots(figsize=(12, 7))
    
    # 1. Define a common X-axis for interpolation (e.g., 0 to 300 in 100 steps)
    common_x = np.linspace(0, max_budget, 100)
    
    interp_recalls = []
    interp_ratios = []
    
    # Colors
    color_recall = 'tab:blue'
    color_ratio = 'tab:red'
    
    # 2. Process each split
    for i, history in enumerate(cv_histories):
        # Unpack data
        x = history['candidates']
        y_rec = history['recall']
        y_rat = [0] + history['ratios'] # Pad ratio with 0 for index 0 to match length
        
        # Ensure x is strictly increasing for interpolation (remove duplicates if any)
        # Usually not needed but good safety
        _, unique_indices = np.unique(x, return_index=True)
        x = np.array(x)[unique_indices]
        y_rec = np.array(y_rec)[unique_indices]
        y_rat = np.array(y_rat)[unique_indices]

        # Interpolate to common grid
        f_rec = interp1d(x, y_rec, kind='linear', bounds_error=False, fill_value="extrapolate")
        f_rat = interp1d(x, y_rat, kind='linear', bounds_error=False, fill_value=0)
        
        interp_recalls.append(f_rec(common_x))
        interp_ratios.append(f_rat(common_x))
        
        # Plot individual faint lines (Spaghetti plot)
        ax1.plot(x, y_rec, color=color_recall, alpha=0.15, linewidth=1)

    # 3. Calculate Mean and Std Dev
    mean_recall = np.mean(interp_recalls, axis=0)
    std_recall = np.std(interp_recalls, axis=0)
    
    mean_ratio = np.mean(interp_ratios, axis=0)

    # 4. Plot Mean Recall (Bold)
    ax1.plot(common_x, mean_recall, color=color_recall, linewidth=3, label='Mean Recall')
    
    # Plot Standard Deviation (Shaded Area) - Shows Stability
    ax1.fill_between(common_x, 
                     mean_recall - std_recall, 
                     mean_recall + std_recall, 
                     color=color_recall, alpha=0.2, label='Recall Std Dev')

    ax1.set_xlabel('Average Candidates per User')
    ax1.set_ylabel('Recall', color=color_recall, fontweight='bold')
    ax1.tick_params(axis='y', labelcolor=color_recall)
    ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax1.set_ylim(bottom=0)

    # 5. Plot Mean Ratio (Secondary Axis)
    ax2 = ax1.twinx()
    ax2.plot(common_x, mean_ratio, color=color_ratio, linestyle='--', linewidth=2, label='Mean Marginal Ratio')
    ax2.set_ylabel('Marginal Ratio (Gain/Cost)', color=color_ratio, fontweight='bold')
    ax2.tick_params(axis='y', labelcolor=color_ratio)
    
    # Start Ratio from 0 to avoid huge spikes distorting the view
    ax2.set_ylim(bottom=0, top=np.max(mean_ratio)*1.2)

    plt.title(f'Candidate Selection Stability ({len(cv_histories)} Folds)')
    
    # Combine legends
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2, loc='center right')
    
    plt.show()

# %%
budget = 150
cutoffs = [
    5, 10, 15, 20, 25, 30, 40, 50,    # High precision area
    60, 70, 80, 90, 100,              # Mid range
    120, 140, 160, 180, 200,          # Extended range
    250, 300                          # Deep candidates
]
max_cutoff = max(cutoffs)

URM_train, URM_val = folds[0]  # Using first fold for demonstration
fold_index = 0

# Pre-compute recommendations for all models
user_ids = np.arange(URM_train.shape[0])
model_recs_cache, model_names = precumpute_recommendations(
    URM_train, 
    user_ids, 
    models_mapping, 
    os.path.join(outer_folder, f"fold_{fold_index}"),
    max_cutoff
)

# Perform greedy candidate selection
selected_cutoffs, history_candidates, history_recall, history_ratios = greedy_candidate_selection(
    URM_train, 
    URM_val, 
    model_names, 
    model_recs_cache, 
    cutoffs, 
    budget
)
# Out:
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0NMF'
# NMFRecommender: Loading complete
# Precomputing recommendations for NMF...
# Precomputing recommendations for MultVAE...
# SLIMElasticNetRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0SLIMElasticNet'
# SLIMElasticNetRecommender: Loading complete
# Precomputing recommendations for SLIMElasticNet...
# Selected SLIMElasticNet @ 5. Ratio: 0.30228. Cost: 135475. Avg Candidates: 5.00. RECALL: 0.0673
# Selected EASE_R @ 5. Ratio: 0.25479. Cost: 31948. Avg Candidates: 6.18. RECALL: 0.0807
# Selected SLIMElasticNet @ 10. Ratio: 0.22982. Cost: 109977. Avg Candidates: 10.24. RECALL: 0.1222
# Selected MultVAE @ 5. Ratio: 0.20542. Cost: 51661. Avg Candidates: 12.14. RECALL: 0.1396
# Selected RP3beta @ 5. Ratio: 0.20468. Cost: 35924. Avg Candidates: 13.47. RECALL: 0.1517
# Selected EASE_R @ 10. Ratio: 0.19176. Cost: 36103. Avg Candidates: 14.80. RECALL: 0.1631
# Selected SLIMElasticNet @ 15. Ratio: 0.18628. Cost: 84774. Avg Candidates: 17.93. RECALL: 0.1890
# Selected ItemKNN_asymmetric @ 5. Ratio: 0.16667. Cost: 17520. Avg Candidates: 18.58. RECALL: 0.1938
# Selected IALS @ 5. Ratio: 0.16554. Cost: 34402. Avg Candidates: 19.85. RECALL: 0.2032
# Selected ItemKNN_tversky @ 5. Ratio: 0.15928. Cost: 11935. Avg Candidates: 20.29. RECALL: 0.2063
# Selected SLIMElasticNet @ 20. Ratio: 0.15596. Cost: 99312. Avg Candidates: 23.95. RECALL: 0.2318
# Selected EASE_R @ 15. Ratio: 0.15442. Cost: 21862. Avg Candidates: 24.76. RECALL: 0.2373
# Selected UserKNN_dice @ 5. Ratio: 0.14322. Cost: 20640. Avg Candidates: 25.52. RECALL: 0.2422
# Selected MultVAE @ 10. Ratio: 0.14116. Cost: 42640. Avg Candidates: 27.10. RECALL: 0.2521
# Selected UserKNN_tversky @ 5. Ratio: 0.13392. Cost: 11649. Avg Candidates: 27.53. RECALL: 0.2546
# Selected SLIMElasticNet @ 25. Ratio: 0.13232. Cost: 91906. Avg Candidates: 30.92. RECALL: 0.2746
# Selected IALS @ 10. Ratio: 0.12229. Cost: 38516. Avg Candidates: 32.34. RECALL: 0.2823
# Selected SLIMElasticNet @ 30. Ratio: 0.11955. Cost: 101359. Avg Candidates: 36.08. RECALL: 0.3022
# Selected EASE_R @ 20. Ratio: 0.12519. Cost: 15409. Avg Candidates: 36.65. RECALL: 0.3054
# Selected MultVAE @ 15. Ratio: 0.11321. Cost: 42745. Avg Candidates: 38.23. RECALL: 0.3134
# Selected P3alpha @ 5. Ratio: 0.11266. Cost: 9054. Avg Candidates: 38.56. RECALL: 0.3150
# Selected UserKNN_dice @ 10. Ratio: 0.10226. Cost: 26335. Avg Candidates: 39.53. RECALL: 0.3195
# Selected UserKNN_tversky @ 10. Ratio: 0.10065. Cost: 17128. Avg Candidates: 40.17. RECALL: 0.3223
# Selected SLIMElasticNet @ 40. Ratio: 0.10013. Cost: 196652. Avg Candidates: 47.42. RECALL: 0.3547
# Selected EASE_R @ 25. Ratio: 0.10109. Cost: 13384. Avg Candidates: 47.92. RECALL: 0.3569
# Selected MultVAE @ 20. Ratio: 0.09779. Cost: 42273. Avg Candidates: 49.48. RECALL: 0.3637
# Selected IALS @ 15. Ratio: 0.08976. Cost: 32298. Avg Candidates: 50.67. RECALL: 0.3684
# Selected EASE_R @ 30. Ratio: 0.08548. Cost: 24064. Avg Candidates: 51.56. RECALL: 0.3718
# Selected ItemKNN_cosine @ 5. Ratio: 0.08379. Cost: 4428. Avg Candidates: 51.72. RECALL: 0.3724
# Selected MultVAE @ 25. Ratio: 0.08342. Cost: 49511. Avg Candidates: 53.55. RECALL: 0.3792
# Selected SLIMElasticNet @ 50. Ratio: 0.08247. Cost: 183390. Avg Candidates: 60.32. RECALL: 0.4041
# Selected IALS @ 20. Ratio: 0.07678. Cost: 34829. Avg Candidates: 61.60. RECALL: 0.4085
# Selected UserKNN_dice @ 15. Ratio: 0.07616. Cost: 20916. Avg Candidates: 62.37. RECALL: 0.4111
# Selected MultVAE @ 30. Ratio: 0.07347. Cost: 47228. Avg Candidates: 64.12. RECALL: 0.4168
# Selected UserKNN_tversky @ 15. Ratio: 0.07103. Cost: 15177. Avg Candidates: 64.68. RECALL: 0.4185
# Selected ItemKNN_tversky @ 10. Ratio: 0.07056. Cost: 7412. Avg Candidates: 64.95. RECALL: 0.4194
# Selected SLIMElasticNet @ 60. Ratio: 0.06983. Cost: 193022. Avg Candidates: 72.07. RECALL: 0.4415
# Selected EASE_R @ 40. Ratio: 0.06844. Cost: 30156. Avg Candidates: 73.19. RECALL: 0.4449
# Selected ItemKNN_jaccard @ 5. Ratio: 0.06398. Cost: 3501. Avg Candidates: 73.32. RECALL: 0.4453
# Selected MultVAE @ 40. Ratio: 0.06361. Cost: 99454. Avg Candidates: 76.99. RECALL: 0.4557
# Selected UserKNN_asymmetric @ 5. Ratio: 0.06313. Cost: 396. Avg Candidates: 77.00. RECALL: 0.4557
# Selected UserKNN_cosine @ 5. Ratio: 0.06452. Cost: 248. Avg Candidates: 77.01. RECALL: 0.4558
# Selected ItemKNN_cosine @ 10. Ratio: 0.06100. Cost: 6492. Avg Candidates: 77.25. RECALL: 0.4564
# Selected SLIMElasticNet @ 70. Ratio: 0.06075. Cost: 186843. Avg Candidates: 84.15. RECALL: 0.4751
# Selected IALS @ 25. Ratio: 0.05871. Cost: 28004. Avg Candidates: 85.18. RECALL: 0.4778
# Selected MatrixFactorization_WARP @ 5. Ratio: 0.05873. Cost: 4802. Avg Candidates: 85.36. RECALL: 0.4782
# Selected ItemKNN_dice @ 5. Ratio: 0.05596. Cost: 1769. Avg Candidates: 85.42. RECALL: 0.4784
# Selected IALS @ 30. Ratio: 0.05536. Cost: 35331. Avg Candidates: 86.73. RECALL: 0.4816
# Selected UserKNN_dice @ 20. Ratio: 0.05419. Cost: 15908. Avg Candidates: 87.31. RECALL: 0.4830
# Selected MultVAE @ 50. Ratio: 0.05395. Cost: 104676. Avg Candidates: 91.18. RECALL: 0.4923
# Selected UserKNN_tversky @ 20. Ratio: 0.05417. Cost: 12460. Avg Candidates: 91.64. RECALL: 0.4934
# Selected SLIMElasticNet @ 80. Ratio: 0.05264. Cost: 184747. Avg Candidates: 98.46. RECALL: 0.5094
# Selected UserKNN_dice @ 25. Ratio: 0.04876. Cost: 17330. Avg Candidates: 99.09. RECALL: 0.5108
# Selected IALS @ 40. Ratio: 0.04784. Cost: 76248. Avg Candidates: 101.91. RECALL: 0.5168
# Selected SLIMElasticNet @ 90. Ratio: 0.04654. Cost: 192559. Avg Candidates: 109.02. RECALL: 0.5315
# Selected MultVAE @ 60. Ratio: 0.04569. Cost: 95952. Avg Candidates: 112.56. RECALL: 0.5387
# Selected ItemKNN_jaccard @ 10. Ratio: 0.04438. Cost: 4169. Avg Candidates: 112.71. RECALL: 0.5390
# Selected EASE_R @ 50. Ratio: 0.04409. Cost: 16081. Avg Candidates: 113.30. RECALL: 0.5402
# Selected ItemKNN_cosine @ 15. Ratio: 0.04327. Cost: 5316. Avg Candidates: 113.50. RECALL: 0.5405
# Selected SLIMElasticNet @ 100. Ratio: 0.04201. Cost: 191370. Avg Candidates: 120.56. RECALL: 0.5538
# Selected ItemKNN_dice @ 10. Ratio: 0.04038. Cost: 2600. Avg Candidates: 120.66. RECALL: 0.5539
# Selected MatrixFactorization_WARP @ 10. Ratio: 0.03982. Cost: 5701. Avg Candidates: 120.87. RECALL: 0.5543
# Selected MultVAE @ 70. Ratio: 0.03975. Cost: 104122. Avg Candidates: 124.71. RECALL: 0.5611
# Selected UserKNN_tversky @ 30. Ratio: 0.03941. Cost: 25196. Avg Candidates: 125.64. RECALL: 0.5627
# Selected UserKNN_cosine @ 10. Ratio: 0.04601. Cost: 326. Avg Candidates: 125.65. RECALL: 0.5628
# Selected UserKNN_cosine @ 15. Ratio: 0.04047. Cost: 1186. Avg Candidates: 125.70. RECALL: 0.5628
# Selected UserKNN_asymmetric @ 15. Ratio: 0.04171. Cost: 887. Avg Candidates: 125.73. RECALL: 0.5629
# Selected UserKNN_dice @ 30. Ratio: 0.03948. Cost: 10435. Avg Candidates: 126.12. RECALL: 0.5636
# Selected ItemKNN_cosine @ 20. Ratio: 0.03710. Cost: 6685. Avg Candidates: 126.36. RECALL: 0.5640
# Selected MultVAE @ 80. Ratio: 0.03648. Cost: 119898. Avg Candidates: 130.79. RECALL: 0.5712
# Selected ItemKNN_dice @ 15. Ratio: 0.03633. Cost: 4900. Avg Candidates: 130.97. RECALL: 0.5715
# Selected SLIMElasticNet @ 120. Ratio: 0.03612. Cost: 371880. Avg Candidates: 144.69. RECALL: 0.5935
# Selected MatrixFactorization_WARP @ 15. Ratio: 0.03485. Cost: 6026. Avg Candidates: 144.92. RECALL: 0.5939
# Selected UserKNN_cosine @ 20. Ratio: 0.03519. Cost: 1620. Avg Candidates: 144.98. RECALL: 0.5940
# Selected EASE_R @ 60. Ratio: 0.03428. Cost: 13359. Avg Candidates: 145.47. RECALL: 0.5947
# Selected IALS @ 50. Ratio: 0.03324. Cost: 57213. Avg Candidates: 147.58. RECALL: 0.5979
# Selected MatrixFactorization_WARP @ 20. Ratio: 0.03241. Cost: 9165. Avg Candidates: 147.92. RECALL: 0.5983
# Selected MultVAE @ 90. Ratio: 0.03196. Cost: 110631. Avg Candidates: 152.00. RECALL: 0.6042
# ---------------------------------------------------
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 5, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 15, 'UserKNN_cosine': 20, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 30, 'UserKNN_dice': 30, 'EASE_R': 60, 'P3alpha': 5, 'RP3beta': 5, 'IALS': 50, 'MatrixFactorization_WARP': 20, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}

# %%
print("---------------------------------------------------")
print(f"Candidates: {history_candidates[-1]:.2f}")
print(f"RECALL: {history_recall[-1]:.4f}")
print("Final Selection:", selected_cutoffs)
# Out:
# ---------------------------------------------------
# Candidates: 152.00
# RECALL: 0.6042
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 5, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 15, 'UserKNN_cosine': 20, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 30, 'UserKNN_dice': 30, 'EASE_R': 60, 'P3alpha': 5, 'RP3beta': 5, 'IALS': 50, 'MatrixFactorization_WARP': 20, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}

# %%
URM_train, URM_val = folds[0]  # Using first fold for demonstration
fold_index = 0

# Divide users in cold and warm
n_interactions_per_user = np.ediff1d(URM_train.indptr)
cold_user_mask = n_interactions_per_user <= 20
warm_user_mask = ~cold_user_mask

cold_user_mask.sum(), warm_user_mask.sum()
# Out:
# (np.int64(2978), np.int64(24117))

# %%
#Plot user activity histogram
plt.figure(figsize=(10,6))
plt.hist(n_interactions_per_user, bins=50, range=(0, 100), color='skyblue', edgecolor='black')
plt.title('User Interaction Histogram')
plt.xlabel('Number of Interactions')
plt.ylabel('Number of Users')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
budget = 150
cutoffs = [
    5, 10, 15, 20, 25, 30, 40, 50,    # High precision area
    60, 70, 80, 90, 100,              # Mid range
    120, 140, 160, 180, 200,          # Extended range
    250, 300                          # Deep candidates
]
max_cutoff = max(cutoffs)

URM_train, URM_val = folds[0]  # Using first fold for demonstration
fold_index = 0

# Divide users in cold and warm
n_interactions_per_user = np.ediff1d(URM_train.indptr)
cold_user_mask = n_interactions_per_user <= 20
warm_user_mask = ~cold_user_mask

# Pre-compute recommendations for all models for cold users
cold_user_ids = np.arange(URM_train.shape[0])[cold_user_mask]
model_recs_cache_cold, model_names = precumpute_recommendations(
    URM_train, 
    cold_user_ids, 
    models_mapping, 
    os.path.join(outer_folder, f"fold_{fold_index}"),
    50 # Use smaller cutoff for cold users
)

# Perform greedy candidate selection for cold users
selected_cutoffs, history_candidates, history_recall, history_ratios = greedy_candidate_selection(
    URM_train[cold_user_ids], 
    URM_val[cold_user_ids], 
    model_names, 
    model_recs_cache_cold, 
    cutoffs, 
    50 # Smaller budget for cold users
)

print("---------------------------------------------------")
print(f"Candidates for Cold Users: {history_candidates[-1]:.2f}")
print(f"RECALL for Cold Users: {history_recall[-1]:.4f}")
print("Final Selection for Cold Users:", selected_cutoffs)

# Pre-compute recommendations for all models for warm users
warm_user_ids = np.arange(URM_train.shape[0])[warm_user_mask]
model_recs_cache_warm, model_names = precumpute_recommendations(
    URM_train, 
    warm_user_ids, 
    models_mapping, 
    os.path.join(outer_folder, f"fold_{fold_index}"),
    max_cutoff
)

# Perform greedy candidate selection for warm users
selected_cutoffs, history_candidates, history_recall, history_ratios = greedy_candidate_selection(
    URM_train[warm_user_ids], 
    URM_val[warm_user_ids], 
    model_names, 
    model_recs_cache_warm, 
    cutoffs, 
    budget
)

print("---------------------------------------------------")
print(f"Candidates for Warm Users: {history_candidates[-1]:.2f}")
print(f"RECALL for Warm Users: {history_recall[-1]:.4f}")
print("Final Selection for Warm Users:", selected_cutoffs)
# Out:
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0NMF'
# NMFRecommender: Loading complete
# Precomputing recommendations for NMF...
# Precomputing recommendations for MultVAE...
# SLIMElasticNetRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0SLIMElasticNet'
# SLIMElasticNetRecommender: Loading complete
# Precomputing recommendations for SLIMElasticNet...
# Selected EASE_R @ 5. Ratio: 0.18952. Cost: 14890. Avg Candidates: 5.00. RECALL: 0.1927
# Selected SLIMElasticNet @ 5. Ratio: 0.09871. Cost: 2644. Avg Candidates: 5.89. RECALL: 0.2105
# Selected MultVAE @ 5. Ratio: 0.08521. Cost: 6232. Avg Candidates: 7.98. RECALL: 0.2468
# Selected IALS @ 5. Ratio: 0.07597. Cost: 4436. Avg Candidates: 9.47. RECALL: 0.2698
# Selected EASE_R @ 10. Ratio: 0.06855. Cost: 8578. Avg Candidates: 12.35. RECALL: 0.3100
# Selected UserKNN_asymmetric @ 5. Ratio: 0.05818. Cost: 4280. Avg Candidates: 13.79. RECALL: 0.3270
# Selected SLIMElasticNet @ 10. Ratio: 0.05707. Cost: 3294. Avg Candidates: 14.89. RECALL: 0.3398
# Selected UserKNN_cosine @ 5. Ratio: 0.04767. Cost: 944. Avg Candidates: 15.21. RECALL: 0.3429
# Selected IALS @ 10. Ratio: 0.04501. Cost: 6888. Avg Candidates: 17.52. RECALL: 0.3641
# Selected SLIMElasticNet @ 15. Ratio: 0.03923. Cost: 7546. Avg Candidates: 20.06. RECALL: 0.3843
# Selected UserKNN_dice @ 5. Ratio: 0.03660. Cost: 1175. Avg Candidates: 20.45. RECALL: 0.3872
# Selected IALS @ 15. Ratio: 0.03391. Cost: 8728. Avg Candidates: 23.38. RECALL: 0.4074
# Selected UserKNN_cosine @ 10. Ratio: 0.03127. Cost: 5916. Avg Candidates: 25.37. RECALL: 0.4201
# Selected ItemKNN_tversky @ 5. Ratio: 0.02944. Cost: 917. Avg Candidates: 25.68. RECALL: 0.4219
# Selected SLIMElasticNet @ 20. Ratio: 0.02815. Cost: 7886. Avg Candidates: 28.33. RECALL: 0.4371
# Selected ItemKNN_asymmetric @ 5. Ratio: 0.02587. Cost: 773. Avg Candidates: 28.59. RECALL: 0.4384
# Selected SLIMElasticNet @ 25. Ratio: 0.02540. Cost: 9880. Avg Candidates: 31.90. RECALL: 0.4556
# Selected MatrixFactorization_WARP @ 5. Ratio: 0.02447. Cost: 1757. Avg Candidates: 32.49. RECALL: 0.4585
# Selected ItemKNN_cosine @ 5. Ratio: 0.02419. Cost: 951. Avg Candidates: 32.81. RECALL: 0.4601
# Selected UserKNN_asymmetric @ 10. Ratio: 0.02362. Cost: 1016. Avg Candidates: 33.15. RECALL: 0.4617
# Selected SLIMElasticNet @ 30. Ratio: 0.02290. Cost: 10656. Avg Candidates: 36.73. RECALL: 0.4784
# Selected UserKNN_cosine @ 15. Ratio: 0.02244. Cost: 4990. Avg Candidates: 38.41. RECALL: 0.4860
# Selected UserKNN_asymmetric @ 15. Ratio: 0.02134. Cost: 1687. Avg Candidates: 38.97. RECALL: 0.4885
# Selected MultVAE @ 20. Ratio: 0.01978. Cost: 7484. Avg Candidates: 41.49. RECALL: 0.4986
# Selected IALS @ 20. Ratio: 0.01874. Cost: 5710. Avg Candidates: 43.40. RECALL: 0.5059
# Selected IALS @ 25. Ratio: 0.01817. Cost: 7374. Avg Candidates: 45.88. RECALL: 0.5151
# Selected IALS @ 30. Ratio: 0.01660. Cost: 8855. Avg Candidates: 48.85. RECALL: 0.5251
# Selected ItemKNN_cosine @ 10. Ratio: 0.01627. Cost: 1660. Avg Candidates: 49.41. RECALL: 0.5269
# Selected EASE_R @ 25. Ratio: 0.01573. Cost: 3051. Avg Candidates: 50.44. RECALL: 0.5302
# ---------------------------------------------------
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 10, 'ItemKNN_jaccard': 0, 'ItemKNN_asymmetric': 5, 'ItemKNN_tversky': 5, 'ItemKNN_dice': 0, 'UserKNN_cosine': 15, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 0, 'UserKNN_dice': 5, 'EASE_R': 25, 'P3alpha': 0, 'RP3beta': 0, 'IALS': 30, 'MatrixFactorization_WARP': 5, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 20, 'SLIMElasticNet': 30}
# ---------------------------------------------------
# Candidates for Cold Users: 50.44
# RECALL for Cold Users: 0.5302
# Final Selection for Cold Users: {'TopPop': 0, 'ItemKNN_cosine': 10, 'ItemKNN_jaccard': 0, 'ItemKNN_asymmetric': 5, 'ItemKNN_tversky': 5, 'ItemKNN_dice': 0, 'UserKNN_cosine': 15, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 0, 'UserKNN_dice': 5, 'EASE_R': 25, 'P3alpha': 0, 'RP3beta': 0, 'IALS': 30, 'MatrixFactorization_WARP': 5, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 20, 'SLIMElasticNet': 30}
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0NMF'
# NMFRecommender: Loading complete
# Precomputing recommendations for NMF...
# Precomputing recommendations for MultVAE...
# SLIMElasticNetRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0SLIMElasticNet'
# SLIMElasticNetRecommender: Loading complete
# Precomputing recommendations for SLIMElasticNet...
# Selected SLIMElasticNet @ 5. Ratio: 0.31660. Cost: 120585. Avg Candidates: 5.00. RECALL: 0.0643
# Selected EASE_R @ 5. Ratio: 0.26723. Cost: 29304. Avg Candidates: 6.22. RECALL: 0.0775
# Selected SLIMElasticNet @ 10. Ratio: 0.24890. Cost: 97490. Avg Candidates: 10.26. RECALL: 0.1183
# Selected RP3beta @ 5. Ratio: 0.21777. Cost: 36699. Avg Candidates: 11.78. RECALL: 0.1318
# Selected MultVAE @ 5. Ratio: 0.21620. Cost: 44256. Avg Candidates: 13.61. RECALL: 0.1479
# Selected EASE_R @ 10. Ratio: 0.20619. Cost: 32606. Avg Candidates: 14.97. RECALL: 0.1592
# Selected SLIMElasticNet @ 15. Ratio: 0.20474. Cost: 74958. Avg Candidates: 18.07. RECALL: 0.1850
# Selected ItemKNN_asymmetric @ 5. Ratio: 0.17960. Cost: 15952. Avg Candidates: 18.74. RECALL: 0.1899
# Selected SLIMElasticNet @ 20. Ratio: 0.17444. Cost: 94846. Avg Candidates: 22.67. RECALL: 0.2177
# Selected EASE_R @ 15. Ratio: 0.16994. Cost: 21690. Avg Candidates: 23.57. RECALL: 0.2239
# Selected IALS @ 5. Ratio: 0.16303. Cost: 26836. Avg Candidates: 24.68. RECALL: 0.2313
# Selected ItemKNN_tversky @ 5. Ratio: 0.16056. Cost: 7723. Avg Candidates: 25.00. RECALL: 0.2334
# Selected UserKNN_dice @ 5. Ratio: 0.15365. Cost: 18737. Avg Candidates: 25.78. RECALL: 0.2382
# Selected MultVAE @ 10. Ratio: 0.15113. Cost: 39091. Avg Candidates: 27.40. RECALL: 0.2482
# Selected SLIMElasticNet @ 25. Ratio: 0.14693. Cost: 81787. Avg Candidates: 30.79. RECALL: 0.2684
# Selected UserKNN_tversky @ 5. Ratio: 0.13846. Cost: 9945. Avg Candidates: 31.20. RECALL: 0.2707
# Selected SLIMElasticNet @ 30. Ratio: 0.13242. Cost: 93204. Avg Candidates: 35.07. RECALL: 0.2915
# Selected EASE_R @ 20. Ratio: 0.13818. Cost: 14800. Avg Candidates: 35.68. RECALL: 0.2949
# Selected IALS @ 10. Ratio: 0.12694. Cost: 31077. Avg Candidates: 36.97. RECALL: 0.3016
# Selected P3alpha @ 5. Ratio: 0.12377. Cost: 8459. Avg Candidates: 37.32. RECALL: 0.3033
# Selected MultVAE @ 15. Ratio: 0.12196. Cost: 38456. Avg Candidates: 38.91. RECALL: 0.3112
# Selected SLIMElasticNet @ 40. Ratio: 0.11163. Cost: 181294. Avg Candidates: 46.43. RECALL: 0.3453
# Selected EASE_R @ 25. Ratio: 0.11263. Cost: 12652. Avg Candidates: 46.96. RECALL: 0.3477
# Selected UserKNN_dice @ 10. Ratio: 0.10588. Cost: 17851. Avg Candidates: 47.70. RECALL: 0.3509
# Selected MultVAE @ 20. Ratio: 0.10605. Cost: 38745. Avg Candidates: 49.30. RECALL: 0.3578
# Selected UserKNN_tversky @ 10. Ratio: 0.10136. Cost: 12411. Avg Candidates: 49.82. RECALL: 0.3599
# Selected IALS @ 15. Ratio: 0.09603. Cost: 29605. Avg Candidates: 51.05. RECALL: 0.3647
# Selected EASE_R @ 30. Ratio: 0.09472. Cost: 21316. Avg Candidates: 51.93. RECALL: 0.3681
# Selected ItemKNN_tversky @ 10. Ratio: 0.09303. Cost: 9825. Avg Candidates: 52.34. RECALL: 0.3696
# Selected MultVAE @ 25. Ratio: 0.09148. Cost: 44318. Avg Candidates: 54.17. RECALL: 0.3765
# Selected SLIMElasticNet @ 50. Ratio: 0.09144. Cost: 160000. Avg Candidates: 60.81. RECALL: 0.4011
# Selected ItemKNN_cosine @ 5. Ratio: 0.08676. Cost: 2939. Avg Candidates: 60.93. RECALL: 0.4015
# Selected IALS @ 20. Ratio: 0.08359. Cost: 31357. Avg Candidates: 62.23. RECALL: 0.4059
# Selected ItemKNN_asymmetric @ 10. Ratio: 0.08222. Cost: 9462. Avg Candidates: 62.62. RECALL: 0.4073
# Selected UserKNN_dice @ 15. Ratio: 0.08106. Cost: 18591. Avg Candidates: 63.39. RECALL: 0.4098
# Selected MultVAE @ 30. Ratio: 0.08010. Cost: 42059. Avg Candidates: 65.14. RECALL: 0.4155
# Selected SLIMElasticNet @ 60. Ratio: 0.07757. Cost: 170615. Avg Candidates: 72.21. RECALL: 0.4377
# Selected EASE_R @ 40. Ratio: 0.07656. Cost: 26528. Avg Candidates: 73.31. RECALL: 0.4412
# Selected UserKNN_tversky @ 15. Ratio: 0.07233. Cost: 11849. Avg Candidates: 73.80. RECALL: 0.4426
# Selected MultVAE @ 40. Ratio: 0.06984. Cost: 88729. Avg Candidates: 77.48. RECALL: 0.4530
# Selected ItemKNN_jaccard @ 5. Ratio: 0.06807. Cost: 2953. Avg Candidates: 77.61. RECALL: 0.4534
# Selected SLIMElasticNet @ 70. Ratio: 0.06731. Cost: 164972. Avg Candidates: 84.45. RECALL: 0.4721
# Selected ItemKNN_cosine @ 10. Ratio: 0.06560. Cost: 4924. Avg Candidates: 84.65. RECALL: 0.4726
# Selected IALS @ 25. Ratio: 0.06338. Cost: 25057. Avg Candidates: 85.69. RECALL: 0.4753
# Selected MatrixFactorization_WARP @ 5. Ratio: 0.06230. Cost: 4398. Avg Candidates: 85.87. RECALL: 0.4758
# Selected IALS @ 30. Ratio: 0.06077. Cost: 31396. Avg Candidates: 87.17. RECALL: 0.4790
# Selected MultVAE @ 50. Ratio: 0.05923. Cost: 94670. Avg Candidates: 91.10. RECALL: 0.4884
# Selected UserKNN_cosine @ 5. Ratio: 0.06087. Cost: 230. Avg Candidates: 91.11. RECALL: 0.4884
# Selected UserKNN_dice @ 20. Ratio: 0.05988. Cost: 12725. Avg Candidates: 91.64. RECALL: 0.4897
# Selected UserKNN_asymmetric @ 5. Ratio: 0.06452. Cost: 155. Avg Candidates: 91.64. RECALL: 0.4897
# Selected SLIMElasticNet @ 80. Ratio: 0.05866. Cost: 163864. Avg Candidates: 98.44. RECALL: 0.5059
# Selected ItemKNN_dice @ 5. Ratio: 0.05556. Cost: 1170. Avg Candidates: 98.48. RECALL: 0.5060
# Selected UserKNN_tversky @ 20. Ratio: 0.05545. Cost: 10423. Avg Candidates: 98.92. RECALL: 0.5070
# Selected EASE_R @ 50. Ratio: 0.05297. Cost: 22108. Avg Candidates: 99.83. RECALL: 0.5090
# Selected UserKNN_dice @ 25. Ratio: 0.05258. Cost: 15385. Avg Candidates: 100.47. RECALL: 0.5103
# Selected IALS @ 40. Ratio: 0.05241. Cost: 66092. Avg Candidates: 103.21. RECALL: 0.5162
# Selected P3alpha @ 10. Ratio: 0.05199. Cost: 5020. Avg Candidates: 103.42. RECALL: 0.5166
# Selected SLIMElasticNet @ 90. Ratio: 0.05162. Cost: 163177. Avg Candidates: 110.19. RECALL: 0.5308
# Selected MultVAE @ 60. Ratio: 0.05053. Cost: 84124. Avg Candidates: 113.67. RECALL: 0.5379
# Selected ItemKNN_cosine @ 15. Ratio: 0.04678. Cost: 4810. Avg Candidates: 113.87. RECALL: 0.5383
# Selected SLIMElasticNet @ 100. Ratio: 0.04656. Cost: 169108. Avg Candidates: 120.89. RECALL: 0.5516
# Selected ItemKNN_jaccard @ 10. Ratio: 0.04479. Cost: 3059. Avg Candidates: 121.01. RECALL: 0.5518
# Selected MultVAE @ 70. Ratio: 0.04398. Cost: 92557. Avg Candidates: 124.85. RECALL: 0.5587
# Selected UserKNN_cosine @ 10. Ratio: 0.04457. Cost: 359. Avg Candidates: 124.87. RECALL: 0.5587
# Selected MatrixFactorization_WARP @ 10. Ratio: 0.04303. Cost: 4671. Avg Candidates: 125.06. RECALL: 0.5590
# Selected ItemKNN_dice @ 10. Ratio: 0.04296. Cost: 2188. Avg Candidates: 125.15. RECALL: 0.5592
# Selected ItemKNN_cosine @ 20. Ratio: 0.04260. Cost: 6737. Avg Candidates: 125.43. RECALL: 0.5597
# Selected UserKNN_tversky @ 30. Ratio: 0.04230. Cost: 22177. Avg Candidates: 126.35. RECALL: 0.5612
# Selected UserKNN_cosine @ 15. Ratio: 0.04568. Cost: 1029. Avg Candidates: 126.39. RECALL: 0.5613
# Selected UserKNN_dice @ 30. Ratio: 0.04300. Cost: 9093. Avg Candidates: 126.77. RECALL: 0.5620
# Selected EASE_R @ 60. Ratio: 0.04172. Cost: 20040. Avg Candidates: 127.60. RECALL: 0.5634
# Selected SLIMElasticNet @ 120. Ratio: 0.04051. Cost: 338568. Avg Candidates: 141.64. RECALL: 0.5865
# Selected MultVAE @ 80. Ratio: 0.03921. Cost: 87545. Avg Candidates: 145.27. RECALL: 0.5923
# Selected UserKNN_asymmetric @ 15. Ratio: 0.03872. Cost: 594. Avg Candidates: 145.29. RECALL: 0.5923
# Selected MatrixFactorization_WARP @ 15. Ratio: 0.03725. Cost: 5476. Avg Candidates: 145.52. RECALL: 0.5926
# Selected IALS @ 50. Ratio: 0.03712. Cost: 49969. Avg Candidates: 147.59. RECALL: 0.5958
# Selected MultVAE @ 90. Ratio: 0.03548. Cost: 98723. Avg Candidates: 151.69. RECALL: 0.6017
# ---------------------------------------------------
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 10, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 10, 'UserKNN_cosine': 15, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 30, 'UserKNN_dice': 30, 'EASE_R': 60, 'P3alpha': 10, 'RP3beta': 5, 'IALS': 50, 'MatrixFactorization_WARP': 15, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}
# ---------------------------------------------------
# Candidates for Warm Users: 151.69
# RECALL for Warm Users: 0.6017
# Final Selection for Warm Users: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 10, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 10, 'UserKNN_cosine': 15, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 30, 'UserKNN_dice': 30, 'EASE_R': 60, 'P3alpha': 10, 'RP3beta': 5, 'IALS': 50, 'MatrixFactorization_WARP': 15, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}

# %%
budget = 150
cutoffs = [
    5, 10, 15, 20, 25, 30, 40, 50,    # High precision area
    60, 70, 80, 90, 100,              # Mid range
    120, 140, 160, 180, 200,          # Extended range
    250, 300                          # Deep candidates
]
max_cutoff = max(cutoffs)

selected_cutoffs_all_folds = []
cv_histories = []

for fold_index, (URM_train, URM_val) in enumerate(folds):
    print(f"Processing Fold {fold_index}...")
    
    # Pre-compute recommendations for all models
    user_ids = np.arange(URM_train.shape[0])
    model_recs_cache, model_names = precumpute_recommendations(
        URM_train, 
        user_ids, 
        models_mapping, 
        os.path.join(outer_folder, f"fold_{fold_index}"),
        max_cutoff
    )

    # Perform greedy candidate selection
    selected_cutoffs, history_candidates, history_recall, history_ratios = greedy_candidate_selection(
        URM_train, 
        URM_val, 
        model_names, 
        model_recs_cache, 
        cutoffs, 
        budget
    )

    # Store results
    selected_cutoffs_all_folds.append(selected_cutoffs)
    cv_histories.append({
        'candidates': history_candidates,
        'recall': history_recall,
        'ratios': history_ratios
    })
# Out:
# Processing Fold 0...
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# /home/luigi/.venvs/recsys/lib/python3.13/site-packages/implicit/cpu/als.py:95: RuntimeWarning: OpenBLAS is configured to use 12 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'OPENBLAS_NUM_THREADS=1' or by calling 'threadpoolctl.threadpool_limits(1, "blas")'. Having OpenBLAS use a threadpool can lead to severe performance issues here.
#   check_blas_config()
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0NMF'
# NMFRecommender: Loading complete
# Precomputing recommendations for NMF...
# Precomputing recommendations for MultVAE...
# /home/luigi/RecSys/Recommenders/Neural/MultVAE_PyTorch_Recommender.py:203: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:53.)
#   user_batch_tensor = torch.sparse_csr_tensor(
# SLIMElasticNetRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_0SLIMElasticNet'
# SLIMElasticNetRecommender: Loading complete
# Precomputing recommendations for SLIMElasticNet...
# Selected SLIMElasticNet @ 5. Ratio: 0.30228. Cost: 135475. Avg Candidates: 5.00. RECALL: 0.0673
# Selected EASE_R @ 5. Ratio: 0.25479. Cost: 31948. Avg Candidates: 6.18. RECALL: 0.0807
# Selected SLIMElasticNet @ 10. Ratio: 0.22982. Cost: 109977. Avg Candidates: 10.24. RECALL: 0.1222
# Selected MultVAE @ 5. Ratio: 0.20542. Cost: 51661. Avg Candidates: 12.14. RECALL: 0.1396
# Selected RP3beta @ 5. Ratio: 0.20468. Cost: 35924. Avg Candidates: 13.47. RECALL: 0.1517
# Selected EASE_R @ 10. Ratio: 0.19176. Cost: 36103. Avg Candidates: 14.80. RECALL: 0.1631
# Selected SLIMElasticNet @ 15. Ratio: 0.18628. Cost: 84774. Avg Candidates: 17.93. RECALL: 0.1890
# Selected ItemKNN_asymmetric @ 5. Ratio: 0.16667. Cost: 17520. Avg Candidates: 18.58. RECALL: 0.1938
# Selected IALS @ 5. Ratio: 0.16554. Cost: 34402. Avg Candidates: 19.85. RECALL: 0.2032
# Selected ItemKNN_tversky @ 5. Ratio: 0.15928. Cost: 11935. Avg Candidates: 20.29. RECALL: 0.2063
# Selected SLIMElasticNet @ 20. Ratio: 0.15596. Cost: 99312. Avg Candidates: 23.95. RECALL: 0.2318
# Selected EASE_R @ 15. Ratio: 0.15442. Cost: 21862. Avg Candidates: 24.76. RECALL: 0.2373
# Selected UserKNN_dice @ 5. Ratio: 0.14322. Cost: 20640. Avg Candidates: 25.52. RECALL: 0.2422
# Selected MultVAE @ 10. Ratio: 0.14116. Cost: 42640. Avg Candidates: 27.10. RECALL: 0.2521
# Selected UserKNN_tversky @ 5. Ratio: 0.13392. Cost: 11649. Avg Candidates: 27.53. RECALL: 0.2546
# Selected SLIMElasticNet @ 25. Ratio: 0.13232. Cost: 91906. Avg Candidates: 30.92. RECALL: 0.2746
# Selected IALS @ 10. Ratio: 0.12229. Cost: 38516. Avg Candidates: 32.34. RECALL: 0.2823
# Selected SLIMElasticNet @ 30. Ratio: 0.11955. Cost: 101359. Avg Candidates: 36.08. RECALL: 0.3022
# Selected EASE_R @ 20. Ratio: 0.12519. Cost: 15409. Avg Candidates: 36.65. RECALL: 0.3054
# Selected MultVAE @ 15. Ratio: 0.11321. Cost: 42745. Avg Candidates: 38.23. RECALL: 0.3134
# Selected P3alpha @ 5. Ratio: 0.11266. Cost: 9054. Avg Candidates: 38.56. RECALL: 0.3150
# Selected UserKNN_dice @ 10. Ratio: 0.10226. Cost: 26335. Avg Candidates: 39.53. RECALL: 0.3195
# Selected UserKNN_tversky @ 10. Ratio: 0.10065. Cost: 17128. Avg Candidates: 40.17. RECALL: 0.3223
# Selected SLIMElasticNet @ 40. Ratio: 0.10013. Cost: 196652. Avg Candidates: 47.42. RECALL: 0.3547
# Selected EASE_R @ 25. Ratio: 0.10109. Cost: 13384. Avg Candidates: 47.92. RECALL: 0.3569
# Selected MultVAE @ 20. Ratio: 0.09779. Cost: 42273. Avg Candidates: 49.48. RECALL: 0.3637
# Selected IALS @ 15. Ratio: 0.08976. Cost: 32298. Avg Candidates: 50.67. RECALL: 0.3684
# Selected EASE_R @ 30. Ratio: 0.08548. Cost: 24064. Avg Candidates: 51.56. RECALL: 0.3718
# Selected ItemKNN_cosine @ 5. Ratio: 0.08379. Cost: 4428. Avg Candidates: 51.72. RECALL: 0.3724
# Selected MultVAE @ 25. Ratio: 0.08342. Cost: 49511. Avg Candidates: 53.55. RECALL: 0.3792
# Selected SLIMElasticNet @ 50. Ratio: 0.08247. Cost: 183390. Avg Candidates: 60.32. RECALL: 0.4041
# Selected IALS @ 20. Ratio: 0.07678. Cost: 34829. Avg Candidates: 61.60. RECALL: 0.4085
# Selected UserKNN_dice @ 15. Ratio: 0.07616. Cost: 20916. Avg Candidates: 62.37. RECALL: 0.4111
# Selected MultVAE @ 30. Ratio: 0.07347. Cost: 47228. Avg Candidates: 64.12. RECALL: 0.4168
# Selected UserKNN_tversky @ 15. Ratio: 0.07103. Cost: 15177. Avg Candidates: 64.68. RECALL: 0.4185
# Selected ItemKNN_tversky @ 10. Ratio: 0.07056. Cost: 7412. Avg Candidates: 64.95. RECALL: 0.4194
# Selected SLIMElasticNet @ 60. Ratio: 0.06983. Cost: 193022. Avg Candidates: 72.07. RECALL: 0.4415
# Selected EASE_R @ 40. Ratio: 0.06844. Cost: 30156. Avg Candidates: 73.19. RECALL: 0.4449
# Selected ItemKNN_jaccard @ 5. Ratio: 0.06398. Cost: 3501. Avg Candidates: 73.32. RECALL: 0.4453
# Selected MultVAE @ 40. Ratio: 0.06361. Cost: 99454. Avg Candidates: 76.99. RECALL: 0.4557
# Selected UserKNN_asymmetric @ 5. Ratio: 0.06313. Cost: 396. Avg Candidates: 77.00. RECALL: 0.4557
# Selected UserKNN_cosine @ 5. Ratio: 0.06452. Cost: 248. Avg Candidates: 77.01. RECALL: 0.4558
# Selected ItemKNN_cosine @ 10. Ratio: 0.06100. Cost: 6492. Avg Candidates: 77.25. RECALL: 0.4564
# Selected SLIMElasticNet @ 70. Ratio: 0.06075. Cost: 186843. Avg Candidates: 84.15. RECALL: 0.4751
# Selected IALS @ 25. Ratio: 0.05871. Cost: 28004. Avg Candidates: 85.18. RECALL: 0.4778
# Selected MatrixFactorization_WARP @ 5. Ratio: 0.05873. Cost: 4802. Avg Candidates: 85.36. RECALL: 0.4782
# Selected ItemKNN_dice @ 5. Ratio: 0.05596. Cost: 1769. Avg Candidates: 85.42. RECALL: 0.4784
# Selected IALS @ 30. Ratio: 0.05536. Cost: 35331. Avg Candidates: 86.73. RECALL: 0.4816
# Selected UserKNN_dice @ 20. Ratio: 0.05419. Cost: 15908. Avg Candidates: 87.31. RECALL: 0.4830
# Selected MultVAE @ 50. Ratio: 0.05395. Cost: 104676. Avg Candidates: 91.18. RECALL: 0.4923
# Selected UserKNN_tversky @ 20. Ratio: 0.05417. Cost: 12460. Avg Candidates: 91.64. RECALL: 0.4934
# Selected SLIMElasticNet @ 80. Ratio: 0.05264. Cost: 184747. Avg Candidates: 98.46. RECALL: 0.5094
# Selected UserKNN_dice @ 25. Ratio: 0.04876. Cost: 17330. Avg Candidates: 99.09. RECALL: 0.5108
# Selected IALS @ 40. Ratio: 0.04784. Cost: 76248. Avg Candidates: 101.91. RECALL: 0.5168
# Selected SLIMElasticNet @ 90. Ratio: 0.04654. Cost: 192559. Avg Candidates: 109.02. RECALL: 0.5315
# Selected MultVAE @ 60. Ratio: 0.04569. Cost: 95952. Avg Candidates: 112.56. RECALL: 0.5387
# Selected ItemKNN_jaccard @ 10. Ratio: 0.04438. Cost: 4169. Avg Candidates: 112.71. RECALL: 0.5390
# Selected EASE_R @ 50. Ratio: 0.04409. Cost: 16081. Avg Candidates: 113.30. RECALL: 0.5402
# Selected ItemKNN_cosine @ 15. Ratio: 0.04327. Cost: 5316. Avg Candidates: 113.50. RECALL: 0.5405
# Selected SLIMElasticNet @ 100. Ratio: 0.04201. Cost: 191370. Avg Candidates: 120.56. RECALL: 0.5538
# Selected ItemKNN_dice @ 10. Ratio: 0.04038. Cost: 2600. Avg Candidates: 120.66. RECALL: 0.5539
# Selected MatrixFactorization_WARP @ 10. Ratio: 0.03982. Cost: 5701. Avg Candidates: 120.87. RECALL: 0.5543
# Selected MultVAE @ 70. Ratio: 0.03975. Cost: 104122. Avg Candidates: 124.71. RECALL: 0.5611
# Selected UserKNN_tversky @ 30. Ratio: 0.03941. Cost: 25196. Avg Candidates: 125.64. RECALL: 0.5627
# Selected UserKNN_cosine @ 10. Ratio: 0.04601. Cost: 326. Avg Candidates: 125.65. RECALL: 0.5628
# Selected UserKNN_cosine @ 15. Ratio: 0.04047. Cost: 1186. Avg Candidates: 125.70. RECALL: 0.5628
# Selected UserKNN_asymmetric @ 15. Ratio: 0.04171. Cost: 887. Avg Candidates: 125.73. RECALL: 0.5629
# Selected UserKNN_dice @ 30. Ratio: 0.03948. Cost: 10435. Avg Candidates: 126.12. RECALL: 0.5636
# Selected ItemKNN_cosine @ 20. Ratio: 0.03710. Cost: 6685. Avg Candidates: 126.36. RECALL: 0.5640
# Selected MultVAE @ 80. Ratio: 0.03648. Cost: 119898. Avg Candidates: 130.79. RECALL: 0.5712
# Selected ItemKNN_dice @ 15. Ratio: 0.03633. Cost: 4900. Avg Candidates: 130.97. RECALL: 0.5715
# Selected SLIMElasticNet @ 120. Ratio: 0.03612. Cost: 371880. Avg Candidates: 144.69. RECALL: 0.5935
# Selected MatrixFactorization_WARP @ 15. Ratio: 0.03485. Cost: 6026. Avg Candidates: 144.92. RECALL: 0.5939
# Selected UserKNN_cosine @ 20. Ratio: 0.03519. Cost: 1620. Avg Candidates: 144.98. RECALL: 0.5940
# Selected EASE_R @ 60. Ratio: 0.03428. Cost: 13359. Avg Candidates: 145.47. RECALL: 0.5947
# Selected IALS @ 50. Ratio: 0.03324. Cost: 57213. Avg Candidates: 147.58. RECALL: 0.5979
# Selected MatrixFactorization_WARP @ 20. Ratio: 0.03241. Cost: 9165. Avg Candidates: 147.92. RECALL: 0.5983
# Selected MultVAE @ 90. Ratio: 0.03196. Cost: 110631. Avg Candidates: 152.00. RECALL: 0.6042
# ---------------------------------------------------
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 5, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 15, 'UserKNN_cosine': 20, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 15, 'UserKNN_tversky': 30, 'UserKNN_dice': 30, 'EASE_R': 60, 'P3alpha': 5, 'RP3beta': 5, 'IALS': 50, 'MatrixFactorization_WARP': 20, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}
# Processing Fold 1...
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1NMF'
# NMFRecommender: Loading complete
# Precomputing recommendations for NMF...
# Precomputing recommendations for MultVAE...
# SLIMElasticNetRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_1SLIMElasticNet'
# SLIMElasticNetRecommender: Loading complete
# Precomputing recommendations for SLIMElasticNet...
# Selected SLIMElasticNet @ 5. Ratio: 0.30270. Cost: 135475. Avg Candidates: 5.00. RECALL: 0.0674
# Selected EASE_R @ 5. Ratio: 0.25567. Cost: 32073. Avg Candidates: 6.18. RECALL: 0.0809
# Selected SLIMElasticNet @ 10. Ratio: 0.23083. Cost: 109848. Avg Candidates: 10.24. RECALL: 0.1225
# Selected MultVAE @ 5. Ratio: 0.20449. Cost: 51759. Avg Candidates: 12.15. RECALL: 0.1399
# Selected RP3beta @ 5. Ratio: 0.20303. Cost: 35872. Avg Candidates: 13.47. RECALL: 0.1519
# Selected EASE_R @ 10. Ratio: 0.19015. Cost: 35425. Avg Candidates: 14.78. RECALL: 0.1629
# Selected SLIMElasticNet @ 15. Ratio: 0.18928. Cost: 84885. Avg Candidates: 17.91. RECALL: 0.1893
# Selected IALS @ 5. Ratio: 0.16977. Cost: 35318. Avg Candidates: 19.22. RECALL: 0.1992
# Selected ItemKNN_asymmetric @ 5. Ratio: 0.16301. Cost: 17367. Avg Candidates: 19.86. RECALL: 0.2038
# Selected ItemKNN_tversky @ 5. Ratio: 0.15481. Cost: 11995. Avg Candidates: 20.30. RECALL: 0.2069
# Selected SLIMElasticNet @ 20. Ratio: 0.15326. Cost: 99362. Avg Candidates: 23.97. RECALL: 0.2319
# Selected EASE_R @ 15. Ratio: 0.14878. Cost: 21562. Avg Candidates: 24.76. RECALL: 0.2372
# Selected UserKNN_dice @ 5. Ratio: 0.14231. Cost: 20483. Avg Candidates: 25.52. RECALL: 0.2420
# Selected MultVAE @ 10. Ratio: 0.14216. Cost: 42402. Avg Candidates: 27.08. RECALL: 0.2519
# Selected UserKNN_tversky @ 5. Ratio: 0.13903. Cost: 11717. Avg Candidates: 27.52. RECALL: 0.2546
# Selected SLIMElasticNet @ 25. Ratio: 0.13346. Cost: 92355. Avg Candidates: 30.92. RECALL: 0.2748
# Selected IALS @ 10. Ratio: 0.12388. Cost: 38417. Avg Candidates: 32.34. RECALL: 0.2826
# Selected P3alpha @ 5. Ratio: 0.11797. Cost: 10799. Avg Candidates: 32.74. RECALL: 0.2847
# Selected SLIMElasticNet @ 30. Ratio: 0.11691. Cost: 99906. Avg Candidates: 36.43. RECALL: 0.3039
# Selected EASE_R @ 20. Ratio: 0.11554. Cost: 15025. Avg Candidates: 36.98. RECALL: 0.3068
# Selected MultVAE @ 15. Ratio: 0.11396. Cost: 42385. Avg Candidates: 38.55. RECALL: 0.3147
# Selected UserKNN_dice @ 10. Ratio: 0.10243. Cost: 26390. Avg Candidates: 39.52. RECALL: 0.3191
# Selected SLIMElasticNet @ 40. Ratio: 0.10142. Cost: 199180. Avg Candidates: 46.87. RECALL: 0.3523
# Selected EASE_R @ 25. Ratio: 0.10179. Cost: 13420. Avg Candidates: 47.37. RECALL: 0.3546
# Selected MultVAE @ 20. Ratio: 0.09777. Cost: 43051. Avg Candidates: 48.96. RECALL: 0.3615
# Selected IALS @ 15. Ratio: 0.09235. Cost: 33049. Avg Candidates: 50.18. RECALL: 0.3665
# Selected UserKNN_tversky @ 10. Ratio: 0.08862. Cost: 13293. Avg Candidates: 50.67. RECALL: 0.3684
# Selected ItemKNN_tversky @ 10. Ratio: 0.08822. Cost: 11709. Avg Candidates: 51.10. RECALL: 0.3701
# Selected EASE_R @ 30. Ratio: 0.08360. Cost: 23384. Avg Candidates: 51.96. RECALL: 0.3734
# Selected MultVAE @ 25. Ratio: 0.08209. Cost: 49862. Avg Candidates: 53.80. RECALL: 0.3801
# Selected ItemKNN_cosine @ 5. Ratio: 0.08151. Cost: 3938. Avg Candidates: 53.95. RECALL: 0.3806
# Selected SLIMElasticNet @ 50. Ratio: 0.08131. Cost: 180488. Avg Candidates: 60.61. RECALL: 0.4047
# Selected IALS @ 20. Ratio: 0.07717. Cost: 34871. Avg Candidates: 61.90. RECALL: 0.4091
# Selected UserKNN_dice @ 15. Ratio: 0.07375. Cost: 20963. Avg Candidates: 62.67. RECALL: 0.4117
# Selected UserKNN_tversky @ 15. Ratio: 0.07283. Cost: 15873. Avg Candidates: 63.26. RECALL: 0.4136
# Selected MultVAE @ 30. Ratio: 0.07195. Cost: 46438. Avg Candidates: 64.97. RECALL: 0.4191
# Selected ItemKNN_asymmetric @ 10. Ratio: 0.07025. Cost: 10776. Avg Candidates: 65.37. RECALL: 0.4203
# Selected SLIMElasticNet @ 60. Ratio: 0.06992. Cost: 191345. Avg Candidates: 72.43. RECALL: 0.4423
# Selected EASE_R @ 40. Ratio: 0.06845. Cost: 29364. Avg Candidates: 73.51. RECALL: 0.4456
# Selected IALS @ 25. Ratio: 0.06430. Cost: 35395. Avg Candidates: 74.82. RECALL: 0.4493
# Selected ItemKNN_jaccard @ 5. Ratio: 0.06357. Cost: 3445. Avg Candidates: 74.95. RECALL: 0.4497
# Selected MultVAE @ 40. Ratio: 0.06282. Cost: 95601. Avg Candidates: 78.47. RECALL: 0.4596
# Selected ItemKNN_cosine @ 10. Ratio: 0.06098. Cost: 6363. Avg Candidates: 78.71. RECALL: 0.4602
# Selected SLIMElasticNet @ 70. Ratio: 0.06088. Cost: 182888. Avg Candidates: 85.46. RECALL: 0.4785
# Selected UserKNN_dice @ 20. Ratio: 0.05575. Cost: 16483. Avg Candidates: 86.07. RECALL: 0.4800
# Selected IALS @ 30. Ratio: 0.05482. Cost: 35371. Avg Candidates: 87.37. RECALL: 0.4832
# Selected UserKNN_tversky @ 20. Ratio: 0.05437. Cost: 14052. Avg Candidates: 87.89. RECALL: 0.4844
# Selected SLIMElasticNet @ 80. Ratio: 0.05355. Cost: 196840. Avg Candidates: 95.16. RECALL: 0.5018
# Selected MultVAE @ 50. Ratio: 0.05283. Cost: 91300. Avg Candidates: 98.53. RECALL: 0.5097
# Selected ItemKNN_dice @ 5. Ratio: 0.05120. Cost: 1250. Avg Candidates: 98.57. RECALL: 0.5098
# Selected EASE_R @ 50. Ratio: 0.05067. Cost: 25461. Avg Candidates: 99.51. RECALL: 0.5119
# Selected P3alpha @ 10. Ratio: 0.04998. Cost: 6542. Avg Candidates: 99.75. RECALL: 0.5125
# Selected UserKNN_dice @ 25. Ratio: 0.04866. Cost: 17078. Avg Candidates: 100.38. RECALL: 0.5138
# Selected SLIMElasticNet @ 90. Ratio: 0.04775. Cost: 191406. Avg Candidates: 107.45. RECALL: 0.5288
# Selected MultVAE @ 60. Ratio: 0.04691. Cost: 99851. Avg Candidates: 111.13. RECALL: 0.5365
# Selected UserKNN_tversky @ 25. Ratio: 0.04634. Cost: 12668. Avg Candidates: 111.60. RECALL: 0.5375
# Selected UserKNN_dice @ 30. Ratio: 0.04499. Cost: 17626. Avg Candidates: 112.25. RECALL: 0.5388
# Selected ItemKNN_cosine @ 15. Ratio: 0.04360. Cost: 4908. Avg Candidates: 112.43. RECALL: 0.5392
# Selected SLIMElasticNet @ 100. Ratio: 0.04272. Cost: 193669. Avg Candidates: 119.58. RECALL: 0.5527
# Selected IALS @ 40. Ratio: 0.04192. Cost: 56804. Avg Candidates: 121.68. RECALL: 0.5567
# Selected MultVAE @ 70. Ratio: 0.03993. Cost: 102885. Avg Candidates: 125.47. RECALL: 0.5634
# Selected UserKNN_asymmetric @ 5. Ratio: 0.04132. Cost: 121. Avg Candidates: 125.48. RECALL: 0.5634
# Selected UserKNN_tversky @ 30. Ratio: 0.03900. Cost: 12769. Avg Candidates: 125.95. RECALL: 0.5642
# Selected ItemKNN_cosine @ 20. Ratio: 0.03840. Cost: 7110. Avg Candidates: 126.21. RECALL: 0.5647
# Selected SLIMElasticNet @ 120. Ratio: 0.03717. Cost: 393881. Avg Candidates: 140.75. RECALL: 0.5887
# Selected MultVAE @ 80. Ratio: 0.03608. Cost: 100837. Avg Candidates: 144.47. RECALL: 0.5947
# Selected UserKNN_cosine @ 5. Ratio: 0.03774. Cost: 53. Avg Candidates: 144.47. RECALL: 0.5947
# Selected ItemKNN_jaccard @ 10. Ratio: 0.03715. Cost: 1965. Avg Candidates: 144.54. RECALL: 0.5948
# Selected MatrixFactorization_WARP @ 10. Ratio: 0.03551. Cost: 5153. Avg Candidates: 144.74. RECALL: 0.5951
# Selected UserKNN_dice @ 40. Ratio: 0.03372. Cost: 30698. Avg Candidates: 145.87. RECALL: 0.5968
# Selected ItemKNN_dice @ 10. Ratio: 0.03341. Cost: 1347. Avg Candidates: 145.92. RECALL: 0.5969
# Selected MultVAE @ 90. Ratio: 0.03294. Cost: 113674. Avg Candidates: 150.11. RECALL: 0.6031
# ---------------------------------------------------
# Final Selection: {'TopPop': 0, 'ItemKNN_cosine': 20, 'ItemKNN_jaccard': 10, 'ItemKNN_asymmetric': 10, 'ItemKNN_tversky': 10, 'ItemKNN_dice': 10, 'UserKNN_cosine': 5, 'UserKNN_jaccard': 0, 'UserKNN_asymmetric': 5, 'UserKNN_tversky': 30, 'UserKNN_dice': 40, 'EASE_R': 50, 'P3alpha': 10, 'RP3beta': 5, 'IALS': 40, 'MatrixFactorization_WARP': 10, 'MatrixFactorization_BPR': 0, 'NMF': 0, 'MultVAE': 90, 'SLIMElasticNet': 120}
# Processing Fold 2...
# TopPopRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2TopPop'
# TopPopRecommender: Loading complete
# Precomputing recommendations for TopPop...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2ItemKNN_cosine'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_cosine...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2ItemKNN_jaccard'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_jaccard...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2ItemKNN_asymmetric'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_asymmetric...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2ItemKNN_tversky'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_tversky...
# ItemKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2ItemKNN_dice'
# ItemKNNCFRecommender: Loading complete
# Precomputing recommendations for ItemKNN_dice...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2UserKNN_cosine'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_cosine...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2UserKNN_jaccard'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_jaccard...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2UserKNN_asymmetric'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_asymmetric...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2UserKNN_tversky'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_tversky...
# UserKNNCFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2UserKNN_dice'
# UserKNNCFRecommender: Loading complete
# Precomputing recommendations for UserKNN_dice...
# EASE_R_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2EASE_R'
# EASE_R_Recommender: Loading complete
# Precomputing recommendations for EASE_R...
# P3alphaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2P3alpha'
# P3alphaRecommender: Loading complete
# Precomputing recommendations for P3alpha...
# RP3betaRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2RP3beta'
# RP3betaRecommender: Loading complete
# Precomputing recommendations for RP3beta...
# Precomputing recommendations for IALS...
# MatrixFactorization_WARP_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2MatrixFactorization_WARP'
# MatrixFactorization_WARP_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_WARP...
# MatrixFactorization_BPR_Cython_Recommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2MatrixFactorization_BPR'
# MatrixFactorization_BPR_Cython_Recommender: Loading complete
# Precomputing recommendations for MatrixFactorization_BPR...
# NMFRecommender: Loading model from file '/home/luigi/RecSys/xg_boost_data/models/features/outer_folds/fold_2NMF'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 18
#      16 # Pre-compute recommendations for all models
#      17 user_ids = np.arange(URM_train.shape[0])
# ---> 18 model_recs_cache, model_names = precumpute_recommendations(
#      19     URM_train,
#      20     user_ids,
#      21     models_mapping,
#      22     os.path.join(outer_folder, f"fold_{fold_index}"),
#      23     max_cutoff
#      24 )
#      26 # Perform greedy candidate selection
#      27 selected_cutoffs, history_candidates, history_recall, history_ratios = greedy_candidate_selection(
#      28     URM_train,
#      29     URM_val,
#    (...)     33     budget
#      34 )
#
# Cell In[9], line 4, in precumpute_recommendations(URM_train, user_ids, models_mapping, folder, max_cutoff)
#       2 model_recs_cache = {}
#       3 model_names = []
# ----> 4 for model_name, model in load_models(URM_train, models_mapping, folder, verbose=False):
#       5     print(f"Precomputing recommendations for {model_name}...")
#       6     model_names.append(model_name)
#
# File ~/RecSys/Challenge/utils.py:263, in load_models(URM_train, mapping, model_folder, verbose, unload)
#     261 else:
#     262     model_instance = model_class(URM_train)
# --> 263     model_instance.load_model(model_folder, model_name)
#     265 yield model_name, model_instance
#     267 # CLEANUP: This runs when the caller asks for the NEXT item
#
# File ~/RecSys/Recommenders/BaseRecommender.py:228, in BaseRecommender.load_model(self, folder_path, file_name)
#     225 self._print("Loading model from file '{}'".format(folder_path + file_name))
#     227 dataIO = DataIO(folder_path=folder_path)
# --> 228 data_dict = dataIO.load_data(file_name=file_name)
#     230 for attrib_name in data_dict.keys():
#     231      self.__setattr__(attrib_name, data_dict[attrib_name])
#
# File ~/RecSys/Recommenders/DataIO.py:256, in DataIO.load_data(self, file_name)
#     253 if file_name.startswith("."):
#     254     continue
# --> 256 decompressed_file_path = dataFile.extract(file_name, path = current_temp_folder)
#     257 file_extension = file_name.split(".")[-1]
#     258 attrib_name = file_name[:-len(file_extension)-1]
#
# File /usr/lib/python3.13/zipfile/__init__.py:1770, in ZipFile.extract(self, member, path, pwd)
#    1767 else:
#    1768     path = os.fspath(path)
# -> 1770 return self._extract_member(member, path, pwd)
#
# File /usr/lib/python3.13/zipfile/__init__.py:1850, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1846     return targetpath
#    1848 with self.open(member, pwd=pwd) as source, \
#    1849      open(targetpath, "wb") as target:
# -> 1850     shutil.copyfileobj(source, target)
#    1852 return targetpath
#
# File /usr/lib/python3.13/shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File /usr/lib/python3.13/zipfile/__init__.py:1015, in ZipExtFile.read(self, n)
#    1013 self._offset = 0
#    1014 while n > 0 and not self._eof:
# -> 1015     data = self._read1(n)
#    1016     if n < len(data):
#    1017         self._readbuffer = data
#
# File /usr/lib/python3.13/zipfile/__init__.py:1091, in ZipExtFile._read1(self, n)
#    1089 elif self._compress_type == ZIP_DEFLATED:
#    1090     n = max(n, self.MIN_READ_SIZE)
# -> 1091     data = self._decompressor.decompress(data, n)
#    1092     self._eof = (self._decompressor.eof or
#    1093                  self._compress_left <= 0 and
#    1094                  not self._decompressor.unconsumed_tail)
#    1095     if self._eof:
#
# KeyboardInterrupt:

# %%
plot_cv_history(cv_histories, max_budget=budget)

# %%
selected_cutoffs_all_folds

# %%
avg_selection = {}
for model_name in models_mapping.keys():
    total = sum(fold_selection.get(model_name, 0) for fold_selection in folds_selection)
    avg_selection[model_name] = total // len(folds_selection)

avg_selection

# %%
# Based on average selection and stability, finalize the candidate selection

final_selection = {
    # --- The Heavy Lifters (Keep Maxed) ---
    'SLIMElasticNet': 250,   # Rock solid. Always 250.
    'MultVAE': 200,          # Rock solid. Always 200.
    'IALS': 80,              # Round 78 -> 80
    'EASE_R': 70,            # Average of 68 -> 70
    'UserKNN_tversky': 75,   # Average 74 -> 75
    'UserKNN_dice': 70,      # Average 68 -> 70
    'MatrixFactorization_WARP': 55, # Average 56 -> 55

    # --- The Support (Mid Range) ---
    'ItemKNN_cosine': 30,
    'ItemKNN_jaccard': 25,
    'ItemKNN_dice': 25,      # Round 22 -> 25
    'UserKNN_asymmetric': 25,
    'UserKNN_cosine': 20,    # Round 18 -> 20

    # --- The Minor Corrections (Low Range) ---
    'UserKNN_jaccard': 15,   # Keep it small due to instability
    'ItemKNN_tversky': 10,
    'ItemKNN_asymmetric': 10,
    'P3alpha': 5,            # Keep as filler
    'RP3beta': 5,            # Keep as filler

    # --- The Noise (DROP) ---
    'TopPop': 0,             # Drop (Avg 2)
    'NMF': 0,                # Drop (Avg 1)
    'MatrixFactorization_BPR': 0
}

# %%
# Convert your dictionary to a list for sorting
final_selection = {
    'SLIMElasticNet': 250,
    'MultVAE': 200, 
    'IALS': 80,
    'EASE_R': 70,
    'UserKNN_tversky': 75,
    'UserKNN_dice': 70, 
    'MatrixFactorization_WARP': 55,
    'ItemKNN_cosine': 30,
    'ItemKNN_jaccard': 25,
    'ItemKNN_dice': 25,
    'UserKNN_asymmetric': 25,
    'UserKNN_cosine': 20,
    'UserKNN_jaccard': 15,
    'ItemKNN_tversky': 10,
    'ItemKNN_asymmetric': 10,
    'P3alpha': 5,
    'RP3beta': 5
}

# remove models with 0 cutoff
candidate_mapping = {name: model_class for name, model_class in models_mapping.items() if final_selection.get(name, 0) > 0}

# %%
for fold_index, (URM_train, URM_val) in enumerate(folds):
    print(f"Processing Fold {fold_index}...")
    
    # Pre-compute recommendations for all models
    user_ids = np.arange(URM_train.shape[0])
    model_recs_cache, model_names = precumpute_recommendations(
        URM_train, 
        user_ids, 
        candidate_mapping, 
        os.path.join(outer_folder, f"fold_{fold_index}"),
        250 # SLIMElasticNet max cutoff
    )

    # Load Ground Truth as boolean for fast check
    URM_val_bool = URM_val.astype(bool)
    n_users, n_items = URM_train.shape

    # This mask tracks "What we have already found"
    current_union_mask = sps.csr_matrix((n_users, n_items), dtype=bool)

    # We will store the results here
    marginal_contributions = []

    # 2. ITERATIVE SELECTION
    # We loop until no models are left, picking the best one each time
    remaining_models = list(final_selection.keys())

    print(f"{'Model':<30} | {'Cutoff':<6} | {'New Hits':<8} | {'Cumul Recall':<12}")
    print("-" * 65)

    cumulative_hits = 0
    total_possible_hits = URM_val.nnz

    while remaining_models:
        best_model = None
        best_new_hits = -1
        best_model_mask = None
        
        # Check every remaining model against the CURRENT union
        for model_name in remaining_models:
            cutoff = final_selection[model_name]
            
            # Get the recommendations for this specific cutoff
            # (Assuming model_recs_cache is available as numpy array)
            recs = model_recs_cache[model_name][:, :cutoff]
            
            # Create Sparse Matrix of these recs
            rows = np.repeat(np.arange(n_users), recs.shape[1])
            cols = recs.flatten()
            data = np.ones(len(cols), dtype=bool)
            model_mask = sps.csr_matrix((data, (rows, cols)), shape=(n_users, n_items))
            
            # CRITICAL STEP: Find NEW items
            # Logic: (Model has it) AND (Current Union does NOT have it)
            # In sparse boolean: model_mask > current_union_mask
            new_items_mask = model_mask > current_union_mask
            
            # Check how many of these NEW items are Relevant (Hits)
            new_hits_mask = new_items_mask.multiply(URM_val_bool)
            new_hits_count = new_hits_mask.nnz
            
            if new_hits_count > best_new_hits:
                best_new_hits = new_hits_count
                best_model = model_name
                best_model_mask = model_mask # Save the full mask of the best model
                
        # 3. UPDATE THE UNION
        if best_model is None or best_new_hits <= 0:
            # Stop if no remaining model adds even 1 hit
            break
            
        cumulative_hits += best_new_hits
        recall = cumulative_hits / total_possible_hits
        
        print(f"{best_model:<30} | {final_selection[best_model]:<6} | {best_new_hits:<8} | {recall:.5f}")
        
        # Add the best model's items to the union
        # Logic: Union = Union OR Best_Model
        current_union_mask = current_union_mask + best_model_mask
        
        # Remove from list
        remaining_models.remove(best_model)
        
    print("-" * 65)
    print("Remaining models (redundant):", remaining_models)

# %% [markdown]
# - Fold 1
# Model                          | Cutoff | New Hits | Cumul Recall
# -----------------------------------------------------------------
# SLIMElasticNet                 | 250    | 421532   | 0.69261
# MultVAE                        | 200    | 28737    | 0.73983
# IALS                           | 80     | 1931     | 0.74300
# UserKNN_tversky                | 75     | 1726     | 0.74584
# MatrixFactorization_WARP       | 55     | 707      | 0.74700
# UserKNN_dice                   | 70     | 421      | 0.74769
# ItemKNN_jaccard                | 25     | 66       | 0.74780
# EASE_R                         | 70     | 56       | 0.74789
# ItemKNN_cosine                 | 30     | 42       | 0.74796
# ItemKNN_dice                   | 25     | 25       | 0.74800
# ItemKNN_asymmetric             | 10     | 23       | 0.74804
# UserKNN_asymmetric             | 25     | 8        | 0.74805
# P3alpha                        | 5      | 4        | 0.74806
# RP3beta                        | 5      | 2        | 0.74806
# UserKNN_cosine                 | 20     | 1        | 0.74806
# -----------------------------------------------------------------
# Remaining models (redundant): ['UserKNN_jaccard', 'ItemKNN_tversky']
#
# - Fold 2
# Model                          | Cutoff | New Hits | Cumul Recall
# -----------------------------------------------------------------
# SLIMElasticNet                 | 250    | 422253   | 0.69380
# MultVAE                        | 200    | 28523    | 0.74066
# IALS                           | 80     | 1980     | 0.74392
# UserKNN_tversky                | 75     | 1698     | 0.74671
# MatrixFactorization_WARP       | 55     | 730      | 0.74791
# UserKNN_dice                   | 70     | 362      | 0.74850
# EASE_R                         | 70     | 61       | 0.74860
# ItemKNN_dice                   | 25     | 51       | 0.74868
# ItemKNN_asymmetric             | 10     | 28       | 0.74873
# ItemKNN_cosine                 | 30     | 26       | 0.74877
# ItemKNN_jaccard                | 25     | 16       | 0.74880
# UserKNN_asymmetric             | 25     | 8        | 0.74881
# RP3beta                        | 5      | 5        | 0.74882
# P3alpha                        | 5      | 2        | 0.74882
# UserKNN_cosine                 | 20     | 1        | 0.74883
# ItemKNN_tversky                | 10     | 1        | 0.74883
# -----------------------------------------------------------------
# Remaining models (redundant): ['UserKNN_jaccard']
#
# - Fold 3
# Model                          | Cutoff | New Hits | Cumul Recall
# -----------------------------------------------------------------
# SLIMElasticNet                 | 250    | 421608   | 0.69274
# MultVAE                        | 200    | 29092    | 0.74054
# IALS                           | 80     | 1898     | 0.74366
# UserKNN_tversky                | 75     | 1678     | 0.74641
# MatrixFactorization_WARP       | 55     | 736      | 0.74762
# UserKNN_dice                   | 70     | 415      | 0.74830
# ItemKNN_jaccard                | 25     | 64       | 0.74841
# EASE_R                         | 70     | 45       | 0.74848
# ItemKNN_cosine                 | 30     | 41       | 0.74855
# ItemKNN_asymmetric             | 10     | 26       | 0.74859
# ItemKNN_dice                   | 25     | 22       | 0.74863
# RP3beta                        | 5      | 4        | 0.74864
# UserKNN_asymmetric             | 25     | 3        | 0.74864
# P3alpha                        | 5      | 2        | 0.74864
# -----------------------------------------------------------------
# Remaining models (redundant): ['UserKNN_cosine', 'UserKNN_jaccard', 'ItemKNN_tversky']
#
# - Fold 4
# Model                          | Cutoff | New Hits | Cumul Recall
# -----------------------------------------------------------------
# SLIMElasticNet                 | 250    | 421419   | 0.69243
# MultVAE                        | 200    | 28781    | 0.73972
# IALS                           | 80     | 1990     | 0.74299
# UserKNN_tversky                | 75     | 1633     | 0.74567
# MatrixFactorization_WARP       | 55     | 721      | 0.74685
# UserKNN_dice                   | 70     | 387      | 0.74749
# ItemKNN_jaccard                | 25     | 60       | 0.74759
# EASE_R                         | 70     | 48       | 0.74767
# ItemKNN_cosine                 | 30     | 35       | 0.74773
# ItemKNN_dice                   | 25     | 24       | 0.74776
# ItemKNN_asymmetric             | 10     | 19       | 0.74780
# UserKNN_asymmetric             | 25     | 8        | 0.74781
# P3alpha                        | 5      | 5        | 0.74782
# RP3beta                        | 5      | 4        | 0.74782
# UserKNN_cosine                 | 20     | 1        | 0.74783
# ItemKNN_tversky                | 10     | 1        | 0.74783
# -----------------------------------------------------------------
# Remaining models (redundant): ['UserKNN_jaccard']
#
# - Fold 5
#
# Model                          | Cutoff | New Hits | Cumul Recall
# -----------------------------------------------------------------
# SLIMElasticNet                 | 250    | 421278   | 0.69220
# MultVAE                        | 200    | 29020    | 0.73988
# IALS                           | 80     | 2052     | 0.74325
# UserKNN_tversky                | 75     | 1706     | 0.74605
# MatrixFactorization_WARP       | 55     | 725      | 0.74724
# UserKNN_dice                   | 70     | 424      | 0.74794
# ItemKNN_jaccard                | 25     | 58       | 0.74804
# EASE_R                         | 70     | 54       | 0.74812
# ItemKNN_asymmetric             | 10     | 31       | 0.74818
# ItemKNN_cosine                 | 30     | 23       | 0.74821
# ItemKNN_dice                   | 25     | 15       | 0.74824
# UserKNN_cosine                 | 20     | 4        | 0.74824
# RP3beta                        | 5      | 4        | 0.74825
# UserKNN_asymmetric             | 25     | 2        | 0.74825
# P3alpha                        | 5      | 2        | 0.74826
# ItemKNN_tversky                | 10     | 1        | 0.74826
# -----------------------------------------------------------------
# Remaining models (redundant): ['UserKNN_jaccard']

# %%
final_selection = {
    'SLIMElasticNet': 250,          # The Backbone
    'MultVAE': 200,                 # The Deep Explorer
    'IALS': 80,                     # The Latent Factor
    'UserKNN_tversky': 75,          # The Niche User Finder
    'MatrixFactorization_WARP': 55, # The Ranking Specialist
    'UserKNN_dice': 70              # The Backup User Finder
}
