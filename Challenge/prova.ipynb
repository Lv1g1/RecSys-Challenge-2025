# %%
from getpass import getpass
import sys, os

REPO_NAME = "RecSys-Challenge-2025"
REPO_URL  = f"github.com/Lv1g1/{REPO_NAME}.git"
LOCAL_REPO_PATH = f"/content/{REPO_NAME}"

# Mount Google Drive first (Colab only)
if '/content' in os.getcwd():
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)

# Clone only if not existing
if not os.path.exists(LOCAL_REPO_PATH):
    print("Cloning repo...")
    token = getpass("GitHub Token: ")
    # !git clone https://{token}@{REPO_URL}
else:
    print("Repo already exists — pulling latest changes")
    os.chdir(LOCAL_REPO_PATH)
    # !git pull
    os.chdir("/content")

# Enable import of your modules
if LOCAL_REPO_PATH not in sys.path:
    os.chdir(LOCAL_REPO_PATH)
    sys.path.append(os.getcwd())
    os.chdir("/content")


# Test import
try:
    from Challenge import paths
    print("paths module imported successfully!")
except Exception as e:
    print("Import failed:", e)
# Out:
# Mounted at /content/drive
# Cloning repo...
# GitHub Token: ··········
# Cloning into 'RecSys-Challenge-2025'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 168 (delta 25), reused 168 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (168/168), 7.33 MiB | 14.97 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Running on: local — BASE_DIR = /
# paths module imported successfully!
